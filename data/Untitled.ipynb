# %%
import pandas as pd

# %%
df = pd.read_csv("breweries.csv")

# %%
df.head()
# Out:
#                               obdb_id                             name  \
# 0          10-56-brewing-company-knox            10-56 Brewing Company
# 1           10-barrel-brewing-co-bend             10 Barrel Brewing Co
# 2         10-barrel-brewing-co-bend-2             10 Barrel Brewing Co
# 3  10-barrel-brewing-co-bend-pub-bend  10 Barrel Brewing Co - Bend Pub
# 4    10-barrel-brewing-co-boise-boise     10 Barrel Brewing Co - Boise
#
#   brewery_type                       street address_2 address_3   city  \
# 0        micro                400 Brown Cir       NaN       NaN   Knox
# 1        large                62970 18th St       NaN       NaN   Bend
# 2        large  1135 NW Galveston Ave Ste B       NaN       NaN   Bend
# 3        large             62950 NE 18th St       NaN       NaN   Bend
# 4        large             826 W Bannock St       NaN       NaN  Boise
#
#      state county_province postal_code              website_url       phone  \
# 0  Indiana             NaN       46534                      NaN  6308165790
# 1   Oregon             NaN  97701-9847  http://www.10barrel.com  5415851007
# 2   Oregon             NaN  97703-2465                      NaN  5415851007
# 3   Oregon             NaN       97701                      NaN  5415851007
# 4    Idaho             NaN  83702-5857  http://www.10barrel.com  2083445870
#
#             created_at           updated_at        country   longitude  \
# 0  2018-07-24 01:33:21  2018-08-24 00:32:25  United States  -86.627954
# 1  2018-07-24 01:34:04  2018-08-11 21:39:09  United States         NaN
# 2  2018-07-24 01:34:04  2018-08-11 21:39:09  United States         NaN
# 3  2018-07-24 01:34:04  2018-08-24 15:45:44  United States -121.280954
# 4  2018-07-24 01:33:17  2020-10-11 17:00:13  United States -116.202929
#
#     latitude  tags
# 0  41.289715   NaN
# 1        NaN   NaN
# 2        NaN   NaN
# 3  44.091211   NaN
# 4  43.618516   NaN

# %%
df.isnull().sum()
# Out:
# obdb_id               0
# name                  0
# brewery_type          0
# street              822
# address_2          7852
# address_3          7860
# city                  0
# state                72
# county_province    7789
# postal_code           0
# website_url        1192
# phone               800
# created_at            0
# updated_at            0
# country               0
# longitude          2855
# latitude           2855
# tags               7862
# dtype: int64

# %%
df.shape
# Out:
# (7862, 18)

# %%
df = df[df['longitude'].notna()]

# %%
df = df[df["country"]== "United States"]

# %%
df = df.fillna("Not Available")

# %%
df.head()
# Out:
#                               obdb_id                             name  \
# 0          10-56-brewing-company-knox            10-56 Brewing Company
# 3  10-barrel-brewing-co-bend-pub-bend  10 Barrel Brewing Co - Bend Pub
# 4    10-barrel-brewing-co-boise-boise     10 Barrel Brewing Co - Boise
# 5  10-barrel-brewing-co-denver-denver    10 Barrel Brewing Co - Denver
# 6       10-barrel-brewing-co-portland             10 Barrel Brewing Co
#
#   brewery_type               street      address_2      address_3      city  \
# 0        micro        400 Brown Cir  Not Available  Not Available      Knox
# 3        large     62950 NE 18th St  Not Available  Not Available      Bend
# 4        large     826 W Bannock St  Not Available  Not Available     Boise
# 5        large       2620 Walnut St  Not Available  Not Available    Denver
# 6        large  1411 NW Flanders St  Not Available  Not Available  Portland
#
#       state county_province postal_code              website_url       phone  \
# 0   Indiana   Not Available       46534            Not Available  6308165790
# 3    Oregon   Not Available       97701            Not Available  5415851007
# 4     Idaho   Not Available  83702-5857  http://www.10barrel.com  2083445870
# 5  Colorado   Not Available  80205-2231            Not Available  7205738992
# 6    Oregon   Not Available  97209-2620  http://www.10barrel.com  5032241700
#
#             created_at           updated_at        country   longitude  \
# 0  2018-07-24 01:33:21  2018-08-24 00:32:25  United States  -86.627954
# 3  2018-07-24 01:34:04  2018-08-24 15:45:44  United States -121.280954
# 4  2018-07-24 01:33:17  2020-10-11 17:00:13  United States -116.202929
# 5  2018-07-24 01:33:03  2018-08-24 00:05:11  United States -104.985366
# 6  2018-07-24 01:34:04  2018-08-24 15:45:43  United States -122.685506
#
#     latitude           tags
# 0  41.289715  Not Available
# 3  44.091211  Not Available
# 4  43.618516  Not Available
# 5  39.759251  Not Available
# 6  45.525979  Not Available

# %%
df.head()
# Out:
#                               obdb_id                             name  \
# 0          10-56-brewing-company-knox            10-56 Brewing Company
# 3  10-barrel-brewing-co-bend-pub-bend  10 Barrel Brewing Co - Bend Pub
# 4    10-barrel-brewing-co-boise-boise     10 Barrel Brewing Co - Boise
# 5  10-barrel-brewing-co-denver-denver    10 Barrel Brewing Co - Denver
# 6       10-barrel-brewing-co-portland             10 Barrel Brewing Co
#
#   brewery_type               street      address_2      address_3      city  \
# 0        micro        400 Brown Cir  Not Available  Not Available      Knox
# 3        large     62950 NE 18th St  Not Available  Not Available      Bend
# 4        large     826 W Bannock St  Not Available  Not Available     Boise
# 5        large       2620 Walnut St  Not Available  Not Available    Denver
# 6        large  1411 NW Flanders St  Not Available  Not Available  Portland
#
#       state county_province postal_code              website_url       phone  \
# 0   Indiana   Not Available       46534            Not Available  6308165790
# 3    Oregon   Not Available       97701            Not Available  5415851007
# 4     Idaho   Not Available  83702-5857  http://www.10barrel.com  2083445870
# 5  Colorado   Not Available  80205-2231            Not Available  7205738992
# 6    Oregon   Not Available  97209-2620  http://www.10barrel.com  5032241700
#
#             created_at           updated_at        country   longitude  \
# 0  2018-07-24 01:33:21  2018-08-24 00:32:25  United States  -86.627954
# 3  2018-07-24 01:34:04  2018-08-24 15:45:44  United States -121.280954
# 4  2018-07-24 01:33:17  2020-10-11 17:00:13  United States -116.202929
# 5  2018-07-24 01:33:03  2018-08-24 00:05:11  United States -104.985366
# 6  2018-07-24 01:34:04  2018-08-24 15:45:43  United States -122.685506
#
#     latitude           tags
# 0  41.289715  Not Available
# 3  44.091211  Not Available
# 4  43.618516  Not Available
# 5  39.759251  Not Available
# 6  45.525979  Not Available

# %%
df["region"] = df["state"]

# %%
df.head()
# Out:
#                               obdb_id                             name  \
# 0          10-56-brewing-company-knox            10-56 Brewing Company
# 3  10-barrel-brewing-co-bend-pub-bend  10 Barrel Brewing Co - Bend Pub
# 4    10-barrel-brewing-co-boise-boise     10 Barrel Brewing Co - Boise
# 5  10-barrel-brewing-co-denver-denver    10 Barrel Brewing Co - Denver
# 6       10-barrel-brewing-co-portland             10 Barrel Brewing Co
#
#   brewery_type               street      address_2      address_3      city  \
# 0        micro        400 Brown Cir  Not Available  Not Available      Knox
# 3        large     62950 NE 18th St  Not Available  Not Available      Bend
# 4        large     826 W Bannock St  Not Available  Not Available     Boise
# 5        large       2620 Walnut St  Not Available  Not Available    Denver
# 6        large  1411 NW Flanders St  Not Available  Not Available  Portland
#
#       state county_province postal_code              website_url       phone  \
# 0   Indiana   Not Available       46534            Not Available  6308165790
# 3    Oregon   Not Available       97701            Not Available  5415851007
# 4     Idaho   Not Available  83702-5857  http://www.10barrel.com  2083445870
# 5  Colorado   Not Available  80205-2231            Not Available  7205738992
# 6    Oregon   Not Available  97209-2620  http://www.10barrel.com  5032241700
#
#             created_at           updated_at        country   longitude  \
# 0  2018-07-24 01:33:21  2018-08-24 00:32:25  United States  -86.627954
# 3  2018-07-24 01:34:04  2018-08-24 15:45:44  United States -121.280954
# 4  2018-07-24 01:33:17  2020-10-11 17:00:13  United States -116.202929
# 5  2018-07-24 01:33:03  2018-08-24 00:05:11  United States -104.985366
# 6  2018-07-24 01:34:04  2018-08-24 15:45:43  United States -122.685506
#
#     latitude           tags    region
# 0  41.289715  Not Available   Indiana
# 3  44.091211  Not Available    Oregon
# 4  43.618516  Not Available     Idaho
# 5  39.759251  Not Available  Colorado
# 6  45.525979  Not Available    Oregon

# %%
df["region"].str.replace("Indiana","Midwest")
# Out:
# 0          Midwest
# 3           Oregon
# 4            Idaho
# 5         Colorado
# 6           Oregon
#            ...
# 7855       Midwest
# 7857      Colorado
# 7858       Midwest
# 7860       Florida
# 7861    California
# Name: region, Length: 4936, dtype: object

# %%
df["region"] = df["region"].str.replace("Indiana","Midwest")

# %%
regions = pd.read_csv("regions.csv")

# %%
regions.head()
# Out:
#         State State Code Region            Division
# 0      Alaska         AK   West             Pacific
# 1     Alabama         AL  South  East South Central
# 2    Arkansas         AR  South  West South Central
# 3     Arizona         AZ   West            Mountain
# 4  California         CA   West             Pacific

# %%
regions["state"] = regions["State"]

# %%
final_data = pd.merge(df, regions, how="left", on=["state"])

# %%
final_data.head()
# Out:
#                               obdb_id                             name  \
# 0          10-56-brewing-company-knox            10-56 Brewing Company
# 1  10-barrel-brewing-co-bend-pub-bend  10 Barrel Brewing Co - Bend Pub
# 2    10-barrel-brewing-co-boise-boise     10 Barrel Brewing Co - Boise
# 3  10-barrel-brewing-co-denver-denver    10 Barrel Brewing Co - Denver
# 4       10-barrel-brewing-co-portland             10 Barrel Brewing Co
#
#   brewery_type               street      address_2      address_3      city  \
# 0        micro        400 Brown Cir  Not Available  Not Available      Knox
# 1        large     62950 NE 18th St  Not Available  Not Available      Bend
# 2        large     826 W Bannock St  Not Available  Not Available     Boise
# 3        large       2620 Walnut St  Not Available  Not Available    Denver
# 4        large  1411 NW Flanders St  Not Available  Not Available  Portland
#
#       state county_province postal_code  ...           updated_at  \
# 0   Indiana   Not Available       46534  ...  2018-08-24 00:32:25
# 1    Oregon   Not Available       97701  ...  2018-08-24 15:45:44
# 2     Idaho   Not Available  83702-5857  ...  2020-10-11 17:00:13
# 3  Colorado   Not Available  80205-2231  ...  2018-08-24 00:05:11
# 4    Oregon   Not Available  97209-2620  ...  2018-08-24 15:45:43
#
#          country   longitude   latitude           tags    region     State  \
# 0  United States  -86.627954  41.289715  Not Available   Midwest   Indiana
# 1  United States -121.280954  44.091211  Not Available    Oregon    Oregon
# 2  United States -116.202929  43.618516  Not Available     Idaho     Idaho
# 3  United States -104.985366  39.759251  Not Available  Colorado  Colorado
# 4  United States -122.685506  45.525979  Not Available    Oregon    Oregon
#
#   State Code   Region            Division
# 0         IN  Midwest  East North Central
# 1         OR     West             Pacific
# 2         ID     West            Mountain
# 3         CO     West            Mountain
# 4         OR     West             Pacific
#
# [5 rows x 23 columns]

# %%
address = final_data["street"] + " " + final_data["city"] + " " + final_data["state"] + " " + final_data["postal_code"]
address
# Out:
# 0                        400 Brown Cir Knox Indiana 46534
# 1                      62950 NE 18th St Bend Oregon 97701
# 2                 826 W Bannock St Boise Idaho 83702-5857
# 3               2620 Walnut St Denver Colorado 80205-2231
# 4          1411 NW Flanders St Portland Oregon 97209-2620
#                               ...
# 4931        605 E 9th St Michigan City Indiana 46360-3651
# 4932           2355 W 29th Ave Denver Colorado 80211-3753
# 4933       1038 Lafayette Ave Columbus Indiana 47201-5756
# 4934              1902 E 7th Ave Tampa Florida 33605-3810
# 4935    22755 Hawthorne Blvd Torrance California 90505...
# Length: 4936, dtype: object

# %%
final_data['address'] = address
final_data
# Out:
#                                  obdb_id                             name  \
# 0             10-56-brewing-company-knox            10-56 Brewing Company
# 1     10-barrel-brewing-co-bend-pub-bend  10 Barrel Brewing Co - Bend Pub
# 2       10-barrel-brewing-co-boise-boise     10 Barrel Brewing Co - Boise
# 3     10-barrel-brewing-co-denver-denver    10 Barrel Brewing Co - Denver
# 4          10-barrel-brewing-co-portland             10 Barrel Brewing Co
# ...                                  ...                              ...
# 4931       zorn-brew-works-michigan-city                  Zorn Brew Works
# 4932  zuni-street-brewing-company-denver      Zuni Street Brewing Company
# 4933           zwanzigz-brewing-columbus                 ZwanzigZ Brewing
# 4934             zydeco-brew-werks-tampa                Zydeco Brew Werks
# 4935         zymurgy-brew-works-torrance               Zymurgy Brew Works
#
#      brewery_type                street      address_2      address_3  \
# 0           micro         400 Brown Cir  Not Available  Not Available
# 1           large      62950 NE 18th St  Not Available  Not Available
# 2           large      826 W Bannock St  Not Available  Not Available
# 3           large        2620 Walnut St  Not Available  Not Available
# 4           large   1411 NW Flanders St  Not Available  Not Available
# ...           ...                   ...            ...            ...
# 4931        micro          605 E 9th St  Not Available  Not Available
# 4932        micro       2355 W 29th Ave  Not Available  Not Available
# 4933      brewpub    1038 Lafayette Ave  Not Available  Not Available
# 4934      brewpub        1902 E 7th Ave  Not Available  Not Available
# 4935        micro  22755 Hawthorne Blvd  Not Available  Not Available
#
#                city       state county_province postal_code  ...  \
# 0              Knox     Indiana   Not Available       46534  ...
# 1              Bend      Oregon   Not Available       97701  ...
# 2             Boise       Idaho   Not Available  83702-5857  ...
# 3            Denver    Colorado   Not Available  80205-2231  ...
# 4          Portland      Oregon   Not Available  97209-2620  ...
# ...             ...         ...             ...         ...  ...
# 4931  Michigan City     Indiana   Not Available  46360-3651  ...
# 4932         Denver    Colorado   Not Available  80211-3753  ...
# 4933       Columbus     Indiana   Not Available  47201-5756  ...
# 4934          Tampa     Florida   Not Available  33605-3810  ...
# 4935       Torrance  California   Not Available  90505-3613  ...
#
#             country   longitude   latitude           tags      region  \
# 0     United States  -86.627954  41.289715  Not Available     Midwest
# 1     United States -121.280954  44.091211  Not Available      Oregon
# 2     United States -116.202929  43.618516  Not Available       Idaho
# 3     United States -104.985366  39.759251  Not Available    Colorado
# 4     United States -122.685506  45.525979  Not Available      Oregon
# ...             ...         ...        ...            ...         ...
# 4931  United States  -86.892168  41.714577  Not Available     Midwest
# 4932  United States -105.015409  39.758593  Not Available    Colorado
# 4933  United States  -85.918836  39.208657  Not Available     Midwest
# 4934  United States  -82.437832  27.960344  Not Available     Florida
# 4935  United States -118.352467  33.863537  Not Available  California
#
#            State  State Code   Region            Division  \
# 0        Indiana          IN  Midwest  East North Central
# 1         Oregon          OR     West             Pacific
# 2          Idaho          ID     West            Mountain
# 3       Colorado          CO     West            Mountain
# 4         Oregon          OR     West             Pacific
# ...          ...         ...      ...                 ...
# 4931     Indiana          IN  Midwest  East North Central
# 4932    Colorado          CO     West            Mountain
# 4933     Indiana          IN  Midwest  East North Central
# 4934     Florida          FL    South      South Atlantic
# 4935  California          CA     West             Pacific
#
#                                                 address
# 0                      400 Brown Cir Knox Indiana 46534
# 1                    62950 NE 18th St Bend Oregon 97701
# 2               826 W Bannock St Boise Idaho 83702-5857
# 3             2620 Walnut St Denver Colorado 80205-2231
# 4        1411 NW Flanders St Portland Oregon 97209-2620
# ...                                                 ...
# 4931      605 E 9th St Michigan City Indiana 46360-3651
# 4932         2355 W 29th Ave Denver Colorado 80211-3753
# 4933     1038 Lafayette Ave Columbus Indiana 47201-5756
# 4934            1902 E 7th Ave Tampa Florida 33605-3810
# 4935  22755 Hawthorne Blvd Torrance California 90505...
#
# [4936 rows x 24 columns]

# %%
final_data = final_data[['name', 'brewery_type', 'address', 'state', 'phone', 'website_url', 'country', 'Region', 'Division']]
final_data
# Out:
#                                  name brewery_type  \
# 0               10-56 Brewing Company        micro
# 1     10 Barrel Brewing Co - Bend Pub        large
# 2        10 Barrel Brewing Co - Boise        large
# 3       10 Barrel Brewing Co - Denver        large
# 4                10 Barrel Brewing Co        large
# ...                               ...          ...
# 4931                  Zorn Brew Works        micro
# 4932      Zuni Street Brewing Company        micro
# 4933                 ZwanzigZ Brewing      brewpub
# 4934                Zydeco Brew Werks      brewpub
# 4935               Zymurgy Brew Works        micro
#
#                                                 address       state  \
# 0                      400 Brown Cir Knox Indiana 46534     Indiana
# 1                    62950 NE 18th St Bend Oregon 97701      Oregon
# 2               826 W Bannock St Boise Idaho 83702-5857       Idaho
# 3             2620 Walnut St Denver Colorado 80205-2231    Colorado
# 4        1411 NW Flanders St Portland Oregon 97209-2620      Oregon
# ...                                                 ...         ...
# 4931      605 E 9th St Michigan City Indiana 46360-3651     Indiana
# 4932         2355 W 29th Ave Denver Colorado 80211-3753    Colorado
# 4933     1038 Lafayette Ave Columbus Indiana 47201-5756     Indiana
# 4934            1902 E 7th Ave Tampa Florida 33605-3810     Florida
# 4935  22755 Hawthorne Blvd Torrance California 90505...  California
#
#            phone                       website_url        country   Region  \
# 0     6308165790                     Not Available  United States  Midwest
# 1     5415851007                     Not Available  United States     West
# 2     2083445870           http://www.10barrel.com  United States     West
# 3     7205738992                     Not Available  United States     West
# 4     5032241700           http://www.10barrel.com  United States     West
# ...          ...                               ...            ...      ...
# 4931  2193316322      http://www.zornbrewworks.com  United States  Midwest
# 4932  3038626525  http://www.zunistreetbrewing.com  United States     West
# 4933  8123760200           http://www.zwanzigz.com  United States  Midwest
# 4934  8132524541                     Not Available  United States    South
# 4935  3106502474   http://www.zymurgybrewworks.com  United States     West
#
#                 Division
# 0     East North Central
# 1                Pacific
# 2               Mountain
# 3               Mountain
# 4                Pacific
# ...                  ...
# 4931  East North Central
# 4932            Mountain
# 4933  East North Central
# 4934      South Atlantic
# 4935             Pacific
#
# [4936 rows x 9 columns]

# %%
final_data = final_data.rename(columns={'Region': 'region', 'Division': 'division'})
final_data
# Out:
#                                  name brewery_type  \
# 0               10-56 Brewing Company        micro
# 1     10 Barrel Brewing Co - Bend Pub        large
# 2        10 Barrel Brewing Co - Boise        large
# 3       10 Barrel Brewing Co - Denver        large
# 4                10 Barrel Brewing Co        large
# ...                               ...          ...
# 4931                  Zorn Brew Works        micro
# 4932      Zuni Street Brewing Company        micro
# 4933                 ZwanzigZ Brewing      brewpub
# 4934                Zydeco Brew Werks      brewpub
# 4935               Zymurgy Brew Works        micro
#
#                                                 address       state  \
# 0                      400 Brown Cir Knox Indiana 46534     Indiana
# 1                    62950 NE 18th St Bend Oregon 97701      Oregon
# 2               826 W Bannock St Boise Idaho 83702-5857       Idaho
# 3             2620 Walnut St Denver Colorado 80205-2231    Colorado
# 4        1411 NW Flanders St Portland Oregon 97209-2620      Oregon
# ...                                                 ...         ...
# 4931      605 E 9th St Michigan City Indiana 46360-3651     Indiana
# 4932         2355 W 29th Ave Denver Colorado 80211-3753    Colorado
# 4933     1038 Lafayette Ave Columbus Indiana 47201-5756     Indiana
# 4934            1902 E 7th Ave Tampa Florida 33605-3810     Florida
# 4935  22755 Hawthorne Blvd Torrance California 90505...  California
#
#            phone                       website_url        country   region  \
# 0     6308165790                     Not Available  United States  Midwest
# 1     5415851007                     Not Available  United States     West
# 2     2083445870           http://www.10barrel.com  United States     West
# 3     7205738992                     Not Available  United States     West
# 4     5032241700           http://www.10barrel.com  United States     West
# ...          ...                               ...            ...      ...
# 4931  2193316322      http://www.zornbrewworks.com  United States  Midwest
# 4932  3038626525  http://www.zunistreetbrewing.com  United States     West
# 4933  8123760200           http://www.zwanzigz.com  United States  Midwest
# 4934  8132524541                     Not Available  United States    South
# 4935  3106502474   http://www.zymurgybrewworks.com  United States     West
#
#                 division
# 0     East North Central
# 1                Pacific
# 2               Mountain
# 3               Mountain
# 4                Pacific
# ...                  ...
# 4931  East North Central
# 4932            Mountain
# 4933  East North Central
# 4934      South Atlantic
# 4935             Pacific
#
# [4936 rows x 9 columns]

# %%
final_data = final_data.dropna(how='any')
final_data
# Out:
#                                  name brewery_type  \
# 0               10-56 Brewing Company        micro
# 1     10 Barrel Brewing Co - Bend Pub        large
# 2        10 Barrel Brewing Co - Boise        large
# 3       10 Barrel Brewing Co - Denver        large
# 4                10 Barrel Brewing Co        large
# ...                               ...          ...
# 4931                  Zorn Brew Works        micro
# 4932      Zuni Street Brewing Company        micro
# 4933                 ZwanzigZ Brewing      brewpub
# 4934                Zydeco Brew Werks      brewpub
# 4935               Zymurgy Brew Works        micro
#
#                                                 address       state  \
# 0                      400 Brown Cir Knox Indiana 46534     Indiana
# 1                    62950 NE 18th St Bend Oregon 97701      Oregon
# 2               826 W Bannock St Boise Idaho 83702-5857       Idaho
# 3             2620 Walnut St Denver Colorado 80205-2231    Colorado
# 4        1411 NW Flanders St Portland Oregon 97209-2620      Oregon
# ...                                                 ...         ...
# 4931      605 E 9th St Michigan City Indiana 46360-3651     Indiana
# 4932         2355 W 29th Ave Denver Colorado 80211-3753    Colorado
# 4933     1038 Lafayette Ave Columbus Indiana 47201-5756     Indiana
# 4934            1902 E 7th Ave Tampa Florida 33605-3810     Florida
# 4935  22755 Hawthorne Blvd Torrance California 90505...  California
#
#            phone                       website_url        country   region  \
# 0     6308165790                     Not Available  United States  Midwest
# 1     5415851007                     Not Available  United States     West
# 2     2083445870           http://www.10barrel.com  United States     West
# 3     7205738992                     Not Available  United States     West
# 4     5032241700           http://www.10barrel.com  United States     West
# ...          ...                               ...            ...      ...
# 4931  2193316322      http://www.zornbrewworks.com  United States  Midwest
# 4932  3038626525  http://www.zunistreetbrewing.com  United States     West
# 4933  8123760200           http://www.zwanzigz.com  United States  Midwest
# 4934  8132524541                     Not Available  United States    South
# 4935  3106502474   http://www.zymurgybrewworks.com  United States     West
#
#                 division
# 0     East North Central
# 1                Pacific
# 2               Mountain
# 3               Mountain
# 4                Pacific
# ...                  ...
# 4931  East North Central
# 4932            Mountain
# 4933  East North Central
# 4934      South Atlantic
# 4935             Pacific
#
# [4935 rows x 9 columns]

# %%
final_data.to_csv("breweries_clean.csv",index = False)

# %%
final_data.columns
# Out:
# Index(['obdb_id', 'name', 'brewery_type', 'street', 'address_2', 'address_3',
#        'city', 'state', 'county_province', 'postal_code', 'website_url',
#        'phone', 'created_at', 'updated_at', 'country', 'longitude', 'latitude',
#        'tags', 'region', 'State', 'State Code', 'Region', 'Division'],
#       dtype='object')

# %%
CREATE TABLE persons (
  obdb_id VARCHAR,
  name VARCHAR,
  brewery_type VARCHAR,
  street VARCHAR,
  address_2 VARCHAR,
  address_3 VARCHAR, 
  city VARCHAR,
  state VARCHAR,
  county_province VARCHAR,
  postal_code VARCHAR,
  website_url VARCHAR,
  phone VARCHAR,
  created_at VARCHAR,
  updated_at VARCHAR,
  country VARCHAR,
  longitude VARCHAR,
  latitude VARCHAR,
  tags VARCHAR,
  region VARCHAR,
  State VARCHAR,
  State_Code VARCHAR,
  Region VARCHAR,
  Division VARCHAR)

# %%
import numpy as np

import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

from flask import Flask, jsonify
from sqlalchemy import create_engine

from flask import Response,json

from flask import Flask, jsonify
from flask import Flask, render_template

#################################################
# Database Setup
#################################################
# engine = create_engine("postgres://ucicakrprsnpky:0c02ab311d9965df2f4c471d98f6251dd952fb1263e3962e33a9f4c4ae7fbc78@ec2-54-158-222-248.compute-1.amazonaws.com:5432/dfkdt10l1i8e55")

engine = create_engine("postgres://dijotinjkotssd:db7fb60a896f20e945fe8d81cfa2b4d07537011ed1ffec0d02b3d9407bd982a6@ec2-3-214-3-162.compute-1.amazonaws.com:5432/decuhc9k7edl3j")

# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

# Save reference to the table

results = engine.execute("select * from breweries").fetchall()

# %%
pip install psycopg2
# Out:
# Collecting psycopg2Note: you may need to restart the kernel to use updated packages.
#   Downloading psycopg2-2.8.6-cp36-cp36m-win_amd64.whl (1.1 MB)
# Installing collected packages: psycopg2
# Successfully installed psycopg2-2.8.6

# %%
results[0]
# Out:
# ('10-56-brewing-company-knox', '10-56 Brewing Company', 'micro', '400 Brown Cir', 'Not Available', 'Not Available', 'Knox', 'Indiana', 'Not Available', '46534', 'Not Available', '6308165790', '2018-07-24 01:33:21', '2018-08-24 00:32:25', 'United States', '-86.627954', '41.289715', 'Not Available', 'Midwest', 'Indiana', 'IN', 'Midwest', 'East North Central')

# %%
breweries = []
for i in results:
    breweries.append({'Coordinates':[i[15], i[16]],
                      'Brewery Name': i[1] })

# %%
breweries
# Out:
# [{'Coordinates': ['-86.627954', '41.289715'],
#   'Brewery Name': '10-56 Brewing Company'},
#  {'Coordinates': ['-121.28095359999999', '44.0912109'],
#   'Brewery Name': '10 Barrel Brewing Co - Bend Pub'},
#  {'Coordinates': ['-116.202929', '43.618516'],
#   'Brewery Name': '10 Barrel Brewing Co - Boise'},
#  {'Coordinates': ['-104.9853655', '39.7592508'],
#   'Brewery Name': '10 Barrel Brewing Co - Denver'},
#  {'Coordinates': ['-122.68550559999998', '45.5259786'],
#   'Brewery Name': '10 Barrel Brewing Co'},
#  {'Coordinates': ['-117.129593', '32.714813'],
#   'Brewery Name': '10 Barrel Brewing Co'},
#  {'Coordinates': ['-119.77320149999998', '39.5171702'],
#   'Brewery Name': '10 Torr Distilling and Brewing'},
#  {'Coordinates': ['-104.8667206', '39.38269495'],
#   'Brewery Name': '105 West Brewing Co'},
#  {'Coordinates': ['-93.38952559', '45.19812039'],
#   'Brewery Name': '10K Brewing'},
#  {'Coordinates': ['-70.94594149', '42.10591754'],
#   'Brewery Name': '10th District Brewing Company'},
#  {'Coordinates': ['-95.5186591', '29.951546399999998'],
#   'Brewery Name': '11 Below Brewing Company'},
#  {'Coordinates': ['-118.92187539999999', '44.4146563'],
#   'Brewery Name': '1188 Brewing Co'},
#  {'Coordinates': ['-111.5860662', '33.436188'],
#   'Brewery Name': '12 West Brewing Company - Production Facility'},
#  {'Coordinates': ['-122.485982', '48.762170899999994'],
#   'Brewery Name': '122 West Brewing Co'},
#  {'Coordinates': ['-84.43116792', '42.28667212'],
#   'Brewery Name': '127 Brewing'},
#  {'Coordinates': ['-105.13198259999999', '39.9782443'],
#   'Brewery Name': '12Degree Brewing'},
#  {'Coordinates': ['-84.70634815', '39.12639764'],
#   'Brewery Name': '13 Below Brewery'},
#  {'Coordinates': ['-122.6487531', '45.4762536'],
#   'Brewery Name': '13 Virtues Brewing Co'},
#  {'Coordinates': ['-118.802397', '34.15334'],
#   'Brewery Name': '14 Cannons Brewing Company'},
#  {'Coordinates': ['-104.9839636', '39.761411200000005'],
#   'Brewery Name': '14er Brewing Company'},
#  {'Coordinates': ['-84.3183801', '39.3545967'],
#   'Brewery Name': '16 Lots Brewing'},
#  {'Coordinates': ['-75.37816436', '38.6788938'],
#   'Brewery Name': '16 Mile Brewing Co'},
#  {'Coordinates': ['-75.2565195', '43.24211175'],
#   'Brewery Name': '16 Stone Brewpub'},
#  {'Coordinates': ['-75.97176063', '35.10715368'],
#   'Brewery Name': '1718 Ocracoke Brewing'},
#  {'Coordinates': ['-80.15020356', '40.50984957'],
#   'Brewery Name': '180 and Tapped'},
#  {'Coordinates': ['-88.750264', '34.001703000000006'],
#   'Brewery Name': '1817 Brewery'},
#  {'Coordinates': ['-87.90606942', '43.00436242'],
#   'Brewery Name': '1840 Brewing Company'},
#  {'Coordinates': ['-119.90365919999999', '37.570147999999996'],
#   'Brewery Name': '1850 Brewing Company'},
#  {'Coordinates': ['-87.26887786', '41.59928343'],
#   'Brewery Name': '18th Street Brewery'},
#  {'Coordinates': ['-87.517422', '41.61556796'],
#   'Brewery Name': '18th Street Brewery'},
#  {'Coordinates': ['-89.0503635', '39.5172564'],
#   'Brewery Name': '1905 Brewing Company'},
#  {'Coordinates': ['-110.99275049999999', '32.24673727'],
#   'Brewery Name': '1912 Brewing'},
#  {'Coordinates': ['-122.2415652', '47.75670075'],
#   'Brewery Name': '192 Brewing'},
#  {'Coordinates': ['-110.9004865', '46.54807609'],
#   'Brewery Name': '2 Basset Brewery'},
#  {'Coordinates': ['-75.8800318', '41.8336364'],
#   'Brewery Name': '2 Dogz and A Guy Brewing'},
#  {'Coordinates': ['-68.77283099', '44.80012684'],
#   'Brewery Name': '2 Feet Brewing Company'},
#  {'Coordinates': ['-111.9007652', '40.59502020000001'],
#   'Brewery Name': '2 Row Brewing'},
#  {'Coordinates': ['-82.91181740000002', '40.0030689'],
#   'Brewery Name': '2 Tones Brewing Co.'},
#  {'Coordinates': ['-122.71677290000001', '38.438776700000005'],
#   'Brewery Name': '2 Tread Brewing Co'},
#  {'Coordinates': ['-73.9809868', '41.5082102'],
#   'Brewery Name': '2 Way Brewing Company'},
#  {'Coordinates': ['-79.42125553', '36.58590349'],
#   'Brewery Name': '2 Witches Winery and Brewing Company'},
#  {'Coordinates': ['-122.18421000000001', '48.215096'],
#   'Brewery Name': '210 Brewing Co'},
#  {'Coordinates': ['-77.9120318', '35.7227625'],
#   'Brewery Name': '217 Brew Works'},
#  {'Coordinates': ['-122.39257690000001', '37.782447999999995'],
#   'Brewery Name': '21st Amendment Brewery Cafe'},
#  {'Coordinates': ['-90.21378100000001', '38.624291'],
#   'Brewery Name': '21st St Brewers Bar'},
#  {'Coordinates': ['-95.28093353', '38.9429674'],
#   'Brewery Name': '23rd Street Brewery'},
#  {'Coordinates': ['-80.1224169', '26.231633799999997'],
#   'Brewery Name': '26 Degree Brewing Company'},
#  {'Coordinates': ['-116.55928200000001', '43.578989'],
#   'Brewery Name': '2C Family Brewing Co.'},
#  {'Coordinates': ['-117.137429', '32.896584000000004'],
#   'Brewery Name': '2Kids Brewing Company'},
#  {'Coordinates': ['-90.280526', '38.621943'],
#   'Brewery Name': '2nd Shift Brewing Co'},
#  {'Coordinates': ['-72.7305059', '42.3923659'],
#   'Brewery Name': '3 Beards Beer Company'},
#  {'Coordinates': ['-82.66297209999999', '27.76899022'],
#   'Brewery Name': '3 Daughters Brewing'},
#  {'Coordinates': ['-122.83325020000001', '38.3845125'],
#   'Brewery Name': '3 Disciples Brewing'},
#  {'Coordinates': ['-104.9426656', '39.5659575'],
#   'Brewery Name': '3 Freaks Brewing Co'},
#  {'Coordinates': ['-82.53393502', '27.49645026'],
#   'Brewery Name': '3 Keys Brewing Company, LLC'},
#  {'Coordinates': ['-96.89883128', '32.93044336'],
#   'Brewery Name': '3 Nations Brewing'},
#  {'Coordinates': ['-87.73006524', '43.77384561'],
#   'Brewery Name': '3 Sheeps Brewing Co'},
#  {'Coordinates': ['-80.14361029', '26.04800238'],
#   'Brewery Name': '3 Sons Brewing Co.'},
#  {'Coordinates': ['-94.41265', '39.122384999999994'],
#   'Brewery Name': '3 Trails Brewing Co'},
#  {'Coordinates': ['-78.38636517', '33.97270364'],
#   'Brewery Name': '34 Degree North Experiment Station'},
#  {'Coordinates': ['-87.79160288', '41.55864726'],
#   'Brewery Name': '350 Brewing Co'},
#  {'Coordinates': ['-75.090191', '38.7074994'],
#   'Brewery Name': '38Â°-75Â° Brewing'},
#  {'Coordinates': ['-71.83057593', '42.24364875'],
#   'Brewery Name': '3cross Fermentation Cooperative'},
#  {'Coordinates': ['-94.4190247', '39.246199299999994'],
#   'Brewery Name': '3Halves Brewing Co'},
#  {'Coordinates': ['-78.794223', '35.5914556'],
#   'Brewery Name': '3rd Degree Brewhouse'},
#  {'Coordinates': ['-77.36749285', '35.06939877'],
#   'Brewery Name': '3rd Rock Brewing Company'},
#  {'Coordinates': ['-85.56656078', '38.19322725'],
#   'Brewery Name': '3rd Turn Brewing'},
#  {'Coordinates': ['-93.239889', '37.147985999999996'],
#   'Brewery Name': '4 By 4 Brewing Company'},
#  {'Coordinates': ['-90.19762012', '38.61526593'],
#   'Brewery Name': '4 Hands Brewing Co'},
#  {'Coordinates': ['-97.46818222', '35.25738891'],
#   'Brewery Name': '(405) Brewing Co'},
#  {'Coordinates': ['-119.7088613', '36.7295295'],
#   'Brewery Name': '411 Broadway Ales'},
#  {'Coordinates': ['-78.607989', '42.769311'],
#   'Brewery Name': '42 North Brewing Company'},
#  {'Coordinates': ['-90.02053343', '38.53796122'],
#   'Brewery Name': '4204 Main Street Brewing Co'},
#  {'Coordinates': ['-122.4136168', '37.64425595'],
#   'Brewery Name': '47 Hills Brewing Co'},
#  {'Coordinates': ['-149.8958196', '61.219736600000005'],
#   'Brewery Name': '49th State Brewing Co - Anchorage'},
#  {'Coordinates': ['-149.017877', '63.864759'],
#   'Brewery Name': '49th State Brewing Co'},
#  {'Coordinates': ['-107.92578200000001', '38.900614000000004'],
#   'Brewery Name': "4B's Brewery"},
#  {'Coordinates': ['-84.341647', '41.296252'],
#   'Brewery Name': '4kd Crick Brewery'},
#  {'Coordinates': ['-97.71189129999999', '30.385202399999997'],
#   'Brewery Name': '4th Tap Brewing Cooperative'},
#  {'Coordinates': ['-93.53398788', '43.41926615'],
#   'Brewery Name': '5 Alarm Brewing Co'},
#  {'Coordinates': ['-85.70445518', '42.72497157'],
#   'Brewery Name': '5 Lakes Brewing Co.'},
#  {'Coordinates': ['-87.6572069', '41.75955020000001'],
#   'Brewery Name': '5 Rabbit Cerveceria Inc'},
#  {'Coordinates': ['-122.136104', '48.037428999999996'],
#   'Brewery Name': '5 Rights Brewing Co'},
#  {'Coordinates': ['-87.9152724', '30.674912699999997'],
#   'Brewery Name': '5 Rivers Brewing LLC'},
#  {'Coordinates': ['-84.3796711', '33.9078086'],
#   'Brewery Name': '5 Seasons Brewing Co - Prado'},
#  {'Coordinates': ['-98.232345', '29.711365'],
#   'Brewery Name': '5 Stones Artisan Brewery'},
#  {'Coordinates': ['-93.7228408', '41.599992'],
#   'Brewery Name': '515 Brewing Co'},
#  {'Coordinates': ['-121.20733100000001', '38.8047402'],
#   'Brewery Name': '5150 Brewing At The Brass Tap Rocklin'},
#  {'Coordinates': ['-88.08819', '45.808408'],
#   'Brewery Name': '51st State Brewing Company'},
#  {'Coordinates': ['-87.981157', '41.804494'],
#   'Brewery Name': '51st Ward Beer Company'},
#  {'Coordinates': ['-107.99502350000002', '36.8213739'],
#   'Brewery Name': '550 Brewing'},
#  {'Coordinates': ['-119.7017487', '36.82517171'],
#   'Brewery Name': '559 Local Brewing'},
#  {'Coordinates': ['-88.47806652', '39.13142194'],
#   'Brewery Name': '5770 Brewery'},
#  {'Coordinates': ['-105.1100582', '39.6311085'],
#   'Brewery Name': '6 & 40 Brewery/Taproom'},
#  {'Coordinates': ['-73.86768188', '41.15866213'],
#   'Brewery Name': '6 Degrees of Separation'},
#  {'Coordinates': ['-93.20620579999999', '45.000631'],
#   'Brewery Name': '612 Brew'},
#  {'Coordinates': ['-118.3440213', '34.0730485'],
#   'Brewery Name': '6th and La Brea'},
#  {'Coordinates': ['-124.21475079999999', '43.36654751'],
#   'Brewery Name': '7 Devils Brewing Co'},
#  {'Coordinates': ['-90.66352629999999', '42.5045556'],
#   'Brewery Name': '7 Hills Brewing Company'},
#  {'Coordinates': ['-122.4390379', '47.242614'],
#   'Brewery Name': '7 Seas Brewing Co'},
#  {'Coordinates': ['-79.7497349', '42.24869073'],
#   'Brewery Name': '7 Sins Brewery'},
#  {'Coordinates': ['-120.6706375', '35.2467278'],
#   'Brewery Name': '7 Sisters Brewing Co'},
#  {'Coordinates': ['-88.73129158', '37.15373334'],
#   'Brewery Name': '718BrewCafe, LLP'},
#  {'Coordinates': ['-83.61103475', '42.24586784'],
#   'Brewery Name': '734 Brewing Company'},
#  {'Coordinates': ['-70.87283790000001', '43.1953787'],
#   'Brewery Name': '7th Settlement Brewery'},
#  {'Coordinates': ['-82.45002070000001', '27.9495902'],
#   'Brewery Name': '7venth Sun Tampa'},
#  {'Coordinates': ['-88.71427344', '42.8323014'],
#   'Brewery Name': '841 Brewhouse'},
#  {'Coordinates': ['-118.58853229999998', '34.221801899999996'],
#   'Brewery Name': '8one8 Brewing Company'},
#  {'Coordinates': ['-87.71305702', '43.75674392'],
#   'Brewery Name': '8th Street Ale Haus'},
#  {'Coordinates': ['-95.3559402', '29.748778299999998'],
#   'Brewery Name': '8th Wonder Brewery'},
#  {'Coordinates': ['-96.60698055', '33.61788732'],
#   'Brewery Name': '903 Brewers'},
#  {'Coordinates': ['-121.09854080000001', '35.566672499999996'],
#   'Brewery Name': '927 Beer Company'},
#  {'Coordinates': ['-87.46380305', '41.44400246'],
#   'Brewery Name': '95ate5 Brewpub'},
#  {'Coordinates': ['-81.65451970000001', '30.3108962'],
#   'Brewery Name': 'Aardwolf Brewing Company'},
#  {'Coordinates': ['-80.1402943', '25.789038100000003'],
#   'Brewery Name': 'Abbey Brewing Co'},
#  {'Coordinates': ['-105.9465207', '35.66555826'],
#   'Brewery Name': 'Abbey Brewing Company, LLC'},
#  {'Coordinates': ['-83.93094539', '42.60773722'],
#   'Brewery Name': 'Aberrant Ales'},
#  {'Coordinates': ['-84.76356641', '33.40257035'],
#   'Brewery Name': 'Abide Brewing Company'},
#  {'Coordinates': ['-118.4048656', '33.8734519'], 'Brewery Name': 'Abigaile'},
#  {'Coordinates': ['-71.493705', '42.851742'],
#   'Brewery Name': 'Able Ebenezer Brewing Company'},
#  {'Coordinates': ['-93.2510686', '44.9993934'],
#   'Brewery Name': 'Able Seedhouse and Brewery'},
#  {'Coordinates': ['-117.08575', '33.02391'],
#   'Brewery Name': 'Abnormal Beer Company'},
#  {'Coordinates': ['-77.8607888', '39.28867207'],
#   'Brewery Name': 'Abolitionist Ale Works'},
#  {'Coordinates': ['-84.016459', '35.932287'],
#   'Brewery Name': 'Abridged Beer Company'},
#  {'Coordinates': ['-118.3378601', '33.8431391'],
#   'Brewery Name': 'Absolution Brewing Co'},
#  {'Coordinates': ['-117.27401670000002', '32.84083388'],
#   'Brewery Name': 'Absolution By the Sea'},
#  {'Coordinates': ['-104.819296', '41.130063'],
#   'Brewery Name': 'Accomplice Beer Company'},
#  {'Coordinates': ['-105.10595430000001', '39.53839489999999'],
#   'Brewery Name': 'Acidulous Brewing Company'},
#  {'Coordinates': ['-98.09006208', '30.19269957'],
#   'Brewery Name': 'Acopon Brewing Co'},
#  {'Coordinates': ['-82.90809859999999', '39.986852299999995'],
#   'Brewery Name': 'Actual Brewing Company, LLC'},
#  {'Coordinates': ['-121.970887', '47.85588471'],
#   'Brewery Name': "Adam's Northwest Bistro / Twin Rivers Brewing"},
#  {'Coordinates': ['-97.7201589', '30.382628600000004'],
#   'Brewery Name': "Adelbert's Brewery LLC"},
#  {'Coordinates': ['-73.71407763', '43.41850655'],
#   'Brewery Name': 'Adirondack Pub and Brewery'},
#  {'Coordinates': ['-75.47489238', '44.33237311'],
#   'Brewery Name': 'Adirondack Toboggan Company Microbrewery'},
#  {'Coordinates': ['-77.00942049999999', '38.89742205'],
#   'Brewery Name': 'AdMerk Corp. Inc.'},
#  {'Coordinates': ['-104.984696', '39.739142799999996'],
#   'Brewery Name': 'Aero Craft Brewing'},
#  {'Coordinates': ['-97.35071131', '37.68455054'],
#   'Brewery Name': 'Aero Plains Brewing'},
#  {'Coordinates': ['-71.1062676', '42.3819723'],
#   'Brewery Name': 'Aeronaut Brewing Company'},
#  {'Coordinates': ['-117.14853059999999', '33.49310382'],
#   'Brewery Name': 'Aftershock Brewing Co'},
#  {'Coordinates': ['-88.02234574', '41.90549742'],
#   'Brewery Name': 'Afterthought Brewing Company'},
#  {'Coordinates': ['-85.74403769999999', '38.2554568'],
#   'Brewery Name': 'Against the Grain Brewery'},
#  {'Coordinates': ['-85.7767241', '38.265875799999996'],
#   'Brewery Name': 'Against the Grain Production Facility'},
#  {'Coordinates': ['-71.46899187', '42.9899594'],
#   'Brewery Name': 'Aigean Ales'},
#  {'Coordinates': ['-81.7228141', '33.5603084'],
#   'Brewery Name': 'Aiken Brewing Co'},
#  {'Coordinates': ['-68.3677435', '44.83294620000001'],
#   'Brewery Name': 'Airline Brewing Company'},
#  {'Coordinates': ['-122.235649', '47.382498'],
#   'Brewery Name': 'Airways Brewing Co. Bistro & Beer Garden'},
#  {'Coordinates': ['-122.23910259999998', '47.4119802'],
#   'Brewery Name': 'Airways Brewing Co'},
#  {'Coordinates': ['-83.47153754', '33.94270289'],
#   'Brewery Name': 'Akademia Brewing Company'},
#  {'Coordinates': ['-81.51645882', '41.08512193'],
#   'Brewery Name': 'Akronym Brewing LLC'},
#  {'Coordinates': ['-122.64124950000001', '45.48882655'],
#   'Brewery Name': 'Alameda Brewing Co'},
#  {'Coordinates': ['-122.6136209', '45.54849565'],
#   'Brewery Name': 'Alameda Brewing Co'},
#  {'Coordinates': ['-122.23945060000001', '37.76833631'],
#   'Brewery Name': 'Alameda Island Brewing Company'},
#  {'Coordinates': ['-98.47716379999999', '29.42902321'],
#   'Brewery Name': 'Alamo Beer Co'},
#  {'Coordinates': ['-121.4811835', '38.57323961'],
#   'Brewery Name': 'Alaro Craft Brewery'},
#  {'Coordinates': ['-134.4918763', '58.35681231'],
#   'Brewery Name': 'Alaskan Brewing Co.'},
#  {'Coordinates': ['-92.80737109999998', '41.02718903'],
#   'Brewery Name': 'Albia Brewing Co'},
#  {'Coordinates': ['-84.7532755', '42.2423188'],
#   'Brewery Name': 'Albion Malleable Brewing Company'},
#  {'Coordinates': ['-81.19287028', '29.61781196'],
#   'Brewery Name': 'Alcatraz Brewing'},
#  {'Coordinates': ['-76.98030009', '39.79422185'],
#   'Brewery Name': 'Aldus Brewing Company'},
#  {'Coordinates': ['-89.35416285', '43.12046815'],
#   'Brewery Name': 'Ale Asylum'},
#  {'Coordinates': ['-121.89058329999999', '37.3361905'],
#   'Brewery Name': 'Ale House Brewing Co'},
#  {'Coordinates': ['-122.22818970000002', '37.7761111'],
#   'Brewery Name': 'Ale Industries'},
#  {'Coordinates': ['-87.74301213', '41.94087994'],
#   'Brewery Name': 'Aleman Brewing'},
#  {'Coordinates': ['-78.16559208', '39.18446446'],
#   'Brewery Name': 'Alesatian Brewing Co.'},
#  {'Coordinates': ['-73.95625257', '40.74232214'],
#   'Brewery Name': 'Alewife Brewing Company'},
#  {'Coordinates': ['-119.95371170000001', '39.24819328'],
#   'Brewery Name': 'Alibi Ale Works'},
#  {'Coordinates': ['-117.137429', '32.896584000000004'],
#   'Brewery Name': 'Align Brewing Co'},
#  {'Coordinates': ['-87.66673279999999', '41.8864021'],
#   'Brewery Name': 'All Rise Brewing Co'},
#  {'Coordinates': ['-70.31795179999999', '43.7030951'],
#   'Brewery Name': 'Allagash Brewing Co'},
#  {'Coordinates': ['-80.00061073', '40.45424933'],
#   'Brewery Name': 'Allegheny City Brewing'},
#  {'Coordinates': ['-123.19178059999999', '45.21081917'],
#   'Brewery Name': 'Allegory Brewing'},
#  {'Coordinates': ['-75.4575021', '40.6060468'],
#   'Brewery Name': 'Allentown Brew Works'},
#  {'Coordinates': ['-83.90354690000001', '35.9593516'],
#   'Brewery Name': 'Alliance Brewing Company'},
#  {'Coordinates': ['-82.32225229999999', '29.6502615'],
#   'Brewery Name': "Alligator Brewing / Tall Paul's Brewhouse"},
#  {'Coordinates': ['-93.33543497', '45.16953614'],
#   'Brewery Name': 'Alloy Brewing Company'},
#  {'Coordinates': ['-84.51599645', '38.04950651'],
#   'Brewery Name': "Alltech's Lexington Brewing"},
#  {'Coordinates': ['-84.65887190000001', '43.37888808'],
#   'Brewery Name': 'Alma Brewing Co'},
#  {'Coordinates': ['-94.599389', '39.082495'],
#   'Brewery Name': 'Alma Mader Brewing'},
#  {'Coordinates': ['-122.3062832', '37.78344977'],
#   'Brewery Name': 'Almanac Beer Company'},
#  {'Coordinates': ['-157.857248', '21.301249'],
#   'Brewery Name': 'Aloha Beer Co'},
#  {'Coordinates': ['-117.87814660000001', '34.10365026'],
#   'Brewery Name': 'Alosta Brewing Co'},
#  {'Coordinates': ['-122.1180201', '37.885758200000005'],
#   'Brewery Name': 'Alpenglow Beer Co'},
#  {'Coordinates': ['-90.26236838', '38.59861817'],
#   'Brewery Name': 'Alpha Brewing Co.'},
#  {'Coordinates': ['-117.113975', '32.916779600000005'],
#   'Brewery Name': 'Alpine Beer Company'},
#  {'Coordinates': ['-119.43053059999998', '48.936587700000004'],
#   'Brewery Name': 'Alpine Brewing Co'},
#  {'Coordinates': ['-89.33026', '43.12576305'],
#   'Brewery Name': 'ALT Brew / Greenview Brewing LLC'},
#  {'Coordinates': ['-117.14147120000001', '32.7018758'],
#   'Brewery Name': 'Alta Brewing Company'},
#  {'Coordinates': ['-121.72109740000002', '37.67839114'],
#   'Brewery Name': 'Altamont Beer Works'},
#  {'Coordinates': ['-104.9876117', '39.68866374'],
#   'Brewery Name': 'Alternation Brewing Company'},
#  {'Coordinates': ['-105.5953366', '41.31038565'],
#   'Brewery Name': 'Altitude Chophouse and Brewery'},
#  {'Coordinates': ['-98.84672629999999', '30.246857399999996'],
#   'Brewery Name': 'Altstadt Brewery'},
#  {'Coordinates': ['-121.8946096', '36.59857755'],
#   'Brewery Name': 'Alvarado Street Brewery & Grill'},
#  {'Coordinates': ['-120.849271', '38.4808723'],
#   'Brewery Name': 'Amador Brewing Company'},
#  {'Coordinates': ['-78.132363', '42.7408423'],
#   'Brewery Name': 'Amber Lantern Brewing Company'},
#  {'Coordinates': ['-118.1580493', '33.78538945'],
#   'Brewery Name': 'Ambitious Ales'},
#  {'Coordinates': ['-81.46236272', '30.67106045'],
#   'Brewery Name': 'Amelia Island Brewing Company'},
#  {'Coordinates': ['-85.5378194', '42.26671998'],
#   'Brewery Name': 'American Brewers Inc'},
#  {'Coordinates': ['-83.42868497', '42.419317'],
#   'Brewery Name': 'American Harvest Brewpub At Schoolcraft College'},
#  {'Coordinates': ['-75.859363', '41.254896'],
#   'Brewery Name': 'American Honor Beer Co'},
#  {'Coordinates': ['-80.3955067', '27.63674361'],
#   'Brewery Name': 'American Icon Brewery'},
#  {'Coordinates': ['-95.9667403', '36.1518928'],
#   'Brewery Name': 'American Solera'},
#  {'Coordinates': ['-94.484526', '39.150682'],
#   'Brewery Name': 'Amerisports Brew Pub'},
#  {'Coordinates': ['-72.5318418', '42.3728635'],
#   'Brewery Name': 'Amherst Brewing Co / Hangar Pub and Grill'},
#  {'Coordinates': ['-77.407177', '37.230765000000005'],
#   'Brewery Name': 'Ammo Brewing'},
#  {'Coordinates': ['-71.45315644', '42.43203845'],
#   'Brewery Name': 'Amorys Tomb Brewing Co'},
#  {'Coordinates': ['-117.2511178', '32.7719729'],
#   'Brewery Name': 'Amplified Ale Works'},
#  {'Coordinates': ['-119.2935874', '34.28073347'],
#   'Brewery Name': 'Anacapa Brewing Co'},
#  {'Coordinates': ['-122.61260890000001', '48.51933431'],
#   'Brewery Name': 'Anacortes Brewery/Rockfish Grill'},
#  {'Coordinates': ['-117.91252490000001', '33.8328226'],
#   'Brewery Name': 'Anaheim Brewery'},
#  {'Coordinates': ['-122.7967838', '45.371154600000004'],
#   'Brewery Name': 'Ancestry Brewery'},
#  {'Coordinates': ['-122.4011065', '37.763077200000005'],
#   'Brewery Name': 'Anchor Brewing Co'},
#  {'Coordinates': ['-149.8893581', '61.1385311'],
#   'Brewery Name': 'Anchorage Brewing Co'},
#  {'Coordinates': ['-83.81487799', '35.19958164'],
#   'Brewery Name': 'Andrews Brewing Co At Calaboose Cellars'},
#  {'Coordinates': ['-118.237715', '34.04627065'],
#   'Brewery Name': 'Angel City Brewery'},
#  {'Coordinates': ['-82.45938100000001', '28.005127'],
#   'Brewery Name': 'Angry Chair Brewing, LLC.'},
#  {'Coordinates': ['-108.50760249999999', '45.78022173'],
#   'Brewery Name': "Angry Hank's Microbrewery"},
#  {'Coordinates': ['-118.1003743', '34.0084152'],
#   'Brewery Name': 'Angry Horse Brewing'},
#  {'Coordinates': ['-93.2432718', '44.64760220000001'],
#   'Brewery Name': 'Angry Inch Brewing'},
#  {'Coordinates': ['-106.0764637', '39.63306895'],
#   'Brewery Name': 'Angry James Brewing Co'},
#  {'Coordinates': ['-91.4887672', '46.01048529999999'],
#   'Brewery Name': 'Angry Minnow, The'},
#  {'Coordinates': ['-97.60027690000001', '35.464420600000004'],
#   'Brewery Name': 'Angry Scotsman Brewing'},
#  {'Coordinates': ['-90.2118998', '38.5954536'],
#   'Brewery Name': 'Anheuser-Busch InBev'},
#  {'Coordinates': ['-76.31159343', '43.16510925'],
#   'Brewery Name': 'Anheuser-Busch Inc â\x80\x93 Baldwinsville'},
#  {'Coordinates': ['-82.99306999999999', '40.102197'],
#   'Brewery Name': 'Anheuser-Busch Inc â\x80\x93 Columbus'},
#  {'Coordinates': ['-122.0902992', '38.2365838'],
#   'Brewery Name': 'Anheuser-Busch Inc â\x80\x93 Fairfield'},
#  {'Coordinates': ['-95.27130674', '29.771858'],
#   'Brewery Name': 'Anheuser-Busch Inc â\x80\x93 Houston'},
#  {'Coordinates': ['-81.6481156', '30.431955199999997'],
#   'Brewery Name': 'Anheuser-Busch Inc â\x80\x93 Jacksonville'},
#  {'Coordinates': ['-71.48598162', '42.8253635'],
#   'Brewery Name': 'Anheuser-Busch Inc â\x80\x93 Merrimack'},
#  {'Coordinates': ['-105.0019686', '40.61817811'],
#   'Brewery Name': 'Anheuser-Busch Inc - Fort Collins'},
#  {'Coordinates': ['-118.4721072', '34.22139179999999'],
#   'Brewery Name': 'Anheuser-Busch Inc - Los Angeles'},
#  {'Coordinates': ['-76.6798988', '37.265288899999994'],
#   'Brewery Name': 'Anheuser-Busch Inc ̢���� Williamsburg'},
#  {'Coordinates': ['-107.8769912', '37.27997215'],
#   'Brewery Name': 'Animas Brewing Co'},
#  {'Coordinates': ['-97.5279236', '35.46099673'],
#   'Brewery Name': 'Anthem Brewing Co'},
#  {'Coordinates': ['-82.99774000000001', '39.9476'],
#   'Brewery Name': 'Antiques on High'},
#  {'Coordinates': ['-94.416872', '39.041039000000005'],
#   'Brewery Name': 'Apex Aleworks Brew And BBQ Supplies'},
#  {'Coordinates': ['-79.28917899', '37.36302124'],
#   'Brewery Name': 'Apocalypse Ale Works'},
#  {'Coordinates': ['-85.72031443', '38.256644200000004'],
#   'Brewery Name': 'Apocalypse Brew Works'},
#  {'Coordinates': ['-76.88169609999998', '40.291059000000004'],
#   'Brewery Name': 'Appalachian Brewing Co - Harrisburg'},
#  {'Coordinates': ['-76.30100986', '40.15827375'],
#   'Brewery Name': 'Appalachian Brewing Co - Lititz'},
#  {'Coordinates': ['-81.668461', '36.2033414'],
#   'Brewery Name': 'Appalachian Mountain Brewery - Boone'},
#  {'Coordinates': ['-70.80446020000001', '43.087884'],
#   'Brewery Name': 'Appalachian Mountain Brewery - Portsmouth'},
#  {'Coordinates': ['-94.1372796', '36.1297079'],
#   'Brewery Name': 'Apple Blossom Brewing Co'},
#  {'Coordinates': ['-88.41391479999999', '44.26173602'],
#   'Brewery Name': 'Appleton Beer Factory'},
#  {'Coordinates': ['-81.51788487', '41.0698532'],
#   'Brewery Name': 'Aqueduct Brewing'},
#  {'Coordinates': ['-83.74822471', '42.28041029'],
#   'Brewery Name': 'Arbor Brewing Co'},
#  {'Coordinates': ['-83.6099915', '42.250158'],
#   'Brewery Name': 'Arbor Brewing Co. Microbrewery'},
#  {'Coordinates': ['-85.5715368', '42.2950789'],
#   'Brewery Name': 'Arcadia Brewing Co'},
#  {'Coordinates': ['-93.77320300000001', '39.001467'],
#   'Brewery Name': 'Arcadian Moon'},
#  {'Coordinates': ['-124.4155402', '42.3898306'],
#   'Brewery Name': 'Arch Rock Brewing Co'},
#  {'Coordinates': ['-117.823173', '33.741975399999994'],
#   'Brewery Name': 'Archaic Craft Brewery At Centro'},
#  {'Coordinates': ['-86.25939238', '42.19104832'],
#   'Brewery Name': 'Arclight Brewing Company'},
#  {'Coordinates': ['-77.47201237', '37.568442499999996'],
#   'Brewery Name': 'Ardent Craft Ales'},
#  {'Coordinates': ['-87.61206845', '41.68854885'],
#   'Brewery Name': 'Argus Brewery'},
#  {'Coordinates': ['-73.496758', '43.08767125'],
#   'Brewery Name': 'Argyle Brewing Company'},
#  {'Coordinates': ['-149.103408', '61.582156999999995'],
#   'Brewery Name': 'Arkose Brewery'},
#  {'Coordinates': ['-122.6818596', '45.51786855'],
#   'Brewery Name': 'Arlington Club'},
#  {'Coordinates': ['-72.87397563', '41.29004301'],
#   'Brewery Name': 'Armada Brewing'},
#  {'Coordinates': ['-97.12830051', '33.21286666'],
#   'Brewery Name': 'Armadillo Ale Works'},
#  {'Coordinates': ['-87.79493034', '41.90015593'],
#   'Brewery Name': 'Around the Bend Beer Co.'},
#  {'Coordinates': ['-87.95726941', '41.48205844'],
#   'Brewery Name': 'Arrowhead Ales Brewing Company'},
#  {'Coordinates': ['-74.24891742', '41.80666144'],
#   'Brewery Name': 'Arrowood Farms'},
#  {'Coordinates': ['-74.18803869999999', '39.9625642'],
#   'Brewery Name': "Artisan's Brewery & Italian Grill"},
#  {'Coordinates': ['-118.2357029', '34.04505443'],
#   'Brewery Name': 'Arts District Brewing Company'},
#  {'Coordinates': ['-79.82165390000002', '42.2195527'],
#   'Brewery Name': 'Arundel Cellars & Brewing Co'},
#  {'Coordinates': ['-85.7720434', '42.909271999999994'],
#   'Brewery Name': 'Arvon Brewing Co.'},
#  {'Coordinates': ['-74.01229282', '40.21956661'],
#   'Brewery Name': 'Asbury Park Brewery'},
#  {'Coordinates': ['-83.4609783', '42.4783271'],
#   'Brewery Name': 'Ascension Brewing Company'},
#  {'Coordinates': ['-87.03329688', '35.617454200000005'],
#   'Brewery Name': 'Asgard Brewing Company'},
#  {'Coordinates': ['-95.81621756', '46.09300639'],
#   'Brewery Name': 'Ashby Brewing Company'},
#  {'Coordinates': ['-82.55530545', '35.5917763'],
#   'Brewery Name': 'Asheville Brewing Co'},
#  {'Coordinates': ['-122.9327409', '46.13661987'],
#   'Brewery Name': 'Ashtown Brewing Co'},
#  {'Coordinates': ['-72.23236816', '42.75946232'],
#   'Brewery Name': 'Ashuelot Brewing Company'},
#  {'Coordinates': ['-122.47545090000001', '48.74801531'],
#   'Brewery Name': 'Aslan Brewing Company'},
#  {'Coordinates': ['-122.354134', '47.652201'],
#   'Brewery Name': 'Aslan Brewing Seattle'},
#  {'Coordinates': ['-106.8597747', '39.22153402'],
#   'Brewery Name': 'Aspen Brewing Company'},
#  {'Coordinates': ['-73.2357109', '41.1544649'],
#   'Brewery Name': 'Aspetuck Brew Lab'},
#  {'Coordinates': ['-123.831516', '46.18980259'],
#   'Brewery Name': 'Astoria Brewing Company'},
#  {'Coordinates': ['-121.49439960000001', '38.5815719'],
#   'Brewery Name': 'At Ease Brewing'},
#  {'Coordinates': ['-122.21468670000002', '47.980891799999995'],
#   'Brewery Name': 'At Large Brewing'},
#  {'Coordinates': ['-74.89973165', '39.77167345'],
#   'Brewery Name': 'Atco Brewing LLC'},
#  {'Coordinates': ['-95.852642', '32.205458'],
#   'Brewery Name': 'Athens Brewing Co'},
#  {'Coordinates': ['-68.20607075', '44.389488'],
#   'Brewery Name': 'Atlantic Brewing Co / Bar Harbor Brewing'},
#  {'Coordinates': ['-105.0542327', '40.0488359'],
#   'Brewery Name': 'Atom Brewing Company'},
#  {'Coordinates': ['-119.27820030000001', '46.27475515'],
#   'Brewery Name': 'Atomic Ale Brewpub and Eatery'},
#  {'Coordinates': ['-83.07290400000001', '42.4190883'],
#   'Brewery Name': 'Atwater Brewing Co'},
#  {'Coordinates': ['-85.672454', '42.970463'],
#   'Brewery Name': 'Atwater Grand Rapids'},
#  {'Coordinates': ['-82.9399103', '42.3814617'],
#   'Brewery Name': 'Atwater In the Park Biergarten and Tap House'},
#  {'Coordinates': ['-122.6990459', '48.97900614'],
#   'Brewery Name': 'Atwood Ales'},
#  {'Coordinates': ['-121.07895829999998', '38.89612107'],
#   'Brewery Name': 'Auburn Alehouse'},
#  {'Coordinates': ['-77.17234359', '38.88076482'],
#   'Brewery Name': 'Audacious Aleworks'},
#  {'Coordinates': ['-91.01173472', '38.56026935'],
#   'Brewery Name': 'Augusta Brewing Co'},
#  {'Coordinates': ['-97.44431468', '37.69517328'],
#   'Brewery Name': 'Augustino Brewing'},
#  {'Coordinates': ['-80.02215670000001', '40.4488158'],
#   'Brewery Name': 'Aurochs Brewing Company'},
#  {'Coordinates': ['-97.72984444', '30.379570500000003'],
#   'Brewery Name': 'Austin Beerworks'},
#  {'Coordinates': ['-83.43583578', '45.07296998'],
#   'Brewery Name': "Austin Brothers' Beer Company"},
#  {'Coordinates': ['-117.120151', '32.763588'],
#   'Brewery Name': 'Automatic Brewing Co. / Blind Lady Alehouse'},
#  {'Coordinates': ['-107.664791', '37.809889899999995'],
#   'Brewery Name': 'Avalanche Brewing Co'},
#  {'Coordinates': ['-105.2047652', '40.0625835'],
#   'Brewery Name': 'Avery Brewing Co'},
#  {'Coordinates': ['-78.8073896', '35.61695983'],
#   'Brewery Name': 'Aviator Brewing Company'},
#  {'Coordinates': ['-86.774322', '33.524521'],
#   'Brewery Name': 'Avondale Brewing Co'},
#  {'Coordinates': ['-83.1428144', '42.450802100000004'],
#   'Brewery Name': 'Axle Brewing Company'},
#  {'Coordinates': ['-97.2962784', '27.674993599999997'],
#   'Brewery Name': "B and J's Handcrafted Texas Ales"},
#  {'Coordinates': ['-85.67248446', '42.9638257'],
#   'Brewery Name': "B.O.B's Brewery"},
#  {'Coordinates': ['-76.29904171', '42.49966971'],
#   'Brewery Name': 'Bacchus Brewing'},
#  {'Coordinates': ['-85.83457862', '41.58461971'],
#   'Brewery Name': 'Back Alley Brewing Co'},
#  {'Coordinates': ['-75.97974414', '36.83778371'],
#   'Brewery Name': 'Back Bay Brewing Company'},
#  {'Coordinates': ['-93.64430718', '44.93673794'],
#   'Brewery Name': 'Back Channel Brewing'},
#  {'Coordinates': ['-86.00500600000001', '34.016888'],
#   'Brewery Name': 'Back Forty Beer Co'},
#  {'Coordinates': ['-122.6856562', '45.52597595'],
#   'Brewery Name': 'Back Pedal Brewing Company'},
#  {'Coordinates': ['-86.72649137', '41.6118882'],
#   'Brewery Name': 'Back Road Brewery'},
#  {'Coordinates': ['-117.89608940000001', '33.79983678'],
#   'Brewery Name': 'Back Street Brewery & Tasting Room'},
#  {'Coordinates': ['-98.48671390000001', '29.4330983'],
#   'Brewery Name': 'Back Unturned Brewing Co.'},
#  {'Coordinates': ['-89.5413643', '44.3304949'],
#   'Brewery Name': 'Backcountry Brewing'},
#  {'Coordinates': ['-91.55981337', '41.68139484'],
#   'Brewery Name': 'Backpocket Brewing Co'},
#  {'Coordinates': ['-93.48531767', '41.498501'],
#   'Brewery Name': 'BackRoad Brewery'},
#  {'Coordinates': ['-123.33778810000001', '43.21449839'],
#   'Brewery Name': 'Backside Brewing Co'},
#  {'Coordinates': ['-86.89998607', '40.04207712'],
#   'Brewery Name': 'Backstep Brewing Company'},
#  {'Coordinates': ['-121.82037539999999', '45.72872253'],
#   'Brewery Name': 'Backwoods Brewing Company - Production Only'},
#  {'Coordinates': ['-121.82037539999999', '45.72872253'],
#   'Brewery Name': 'Backwoods in the Gorge'},
#  {'Coordinates': ['-71.4134598', '42.93534925'],
#   'Brewery Name': 'Backyard Brewery'},
#  {'Coordinates': ['-84.4433383', '42.5786176'],
#   'Brewery Name': 'BAD Brewing Co'},
#  {'Coordinates': ['-122.65337360000001', '47.56963921'],
#   'Brewery Name': 'Bad Bulldogs Brewery'},
#  {'Coordinates': ['-70.88353777', '43.22651432'],
#   'Brewery Name': 'Bad Lab Beer Co.'},
#  {'Coordinates': ['-70.52731999999999', '41.394402'],
#   'Brewery Name': "Bad Martha Farmer's Brewery"},
#  {'Coordinates': ['-81.63612015', '38.35094943'],
#   'Brewery Name': 'Bad Shepherd Beer Company'},
#  {'Coordinates': ['-84.41803086', '39.11995755'],
#   'Brewery Name': 'Bad Tom Smith Brewing'},
#  {'Coordinates': ['-81.7051638', '41.48617720000001'],
#   'Brewery Name': 'Bad Tom Smith Brewing'},
#  {'Coordinates': ['-111.9244743', '33.49726157'],
#   'Brewery Name': 'Bad Water Brewing'},
#  {'Coordinates': ['-93.16550009999999', '44.9040455'],
#   'Brewery Name': 'Bad Weather Brewing LLC'},
#  {'Coordinates': ['-117.28291899999999', '47.66990394'],
#   'Brewery Name': 'Badass Backyard Brewing'},
#  {'Coordinates': ['-120.309353', '47.423747'],
#   'Brewery Name': 'Badger Mountain Brewing'},
#  {'Coordinates': ['-88.05136473', '44.49669718'],
#   'Brewery Name': 'Badger State Brewing Company'},
#  {'Coordinates': ['-73.1322771', '41.351364700000005'],
#   'Brewery Name': 'BADSONS Beer Co'},
#  {'Coordinates': ['-77.48972051', '38.75356183'],
#   'Brewery Name': 'BadWolf Brewing Company'},
#  {'Coordinates': ['-122.6550828', '45.50680595'],
#   'Brewery Name': 'Baerlic Brewing Co'},
#  {'Coordinates': ['-82.888964', '42.472227000000004'],
#   'Brewery Name': 'Baffin Brewing Co'},
#  {'Coordinates': ['-117.373847', '33.189591'],
#   'Brewery Name': 'Bagby Beer Company'},
#  {'Coordinates': ['-95.41337465', '29.72562404'],
#   'Brewery Name': 'Baileson Brewing Company, LLC'},
#  {'Coordinates': ['-117.82934709999999', '44.77928865'],
#   'Brewery Name': 'Baker City Brewing Co'},
#  {'Coordinates': ['-95.41741490000001', '29.5551351'],
#   'Brewery Name': 'BAKFISH Brewing Company'},
#  {'Coordinates': ['-78.2625296', '38.377292100000005'],
#   'Brewery Name': 'Bald Top Brewing Company'},
#  {'Coordinates': ['-120.435573', '46.57685541'],
#   'Brewery Name': 'Bale Breaker Brewing Company'},
#  {'Coordinates': ['-131.817681', '55.47290699999999'],
#   'Brewery Name': 'Baleen Brewing Co.'},
#  {'Coordinates': ['-79.386371', '36.584786'],
#   'Brewery Name': 'Ballad Brewing'},
#  {'Coordinates': ['-117.911732', '33.8347516'],
#   'Brewery Name': 'Ballast Point Brewing Company'},
#  {'Coordinates': ['-79.91380298', '37.43575624'],
#   'Brewery Name': 'Ballast Point Brewing Company'},
#  {'Coordinates': ['-117.169738', '32.727777'],
#   'Brewery Name': 'Ballast Point Brewing Company - Little Italy'},
#  {'Coordinates': ['-118.114751', '33.7464176'],
#   'Brewery Name': 'Ballast Point Brewing Company'},
#  {'Coordinates': ['-117.1587251', '32.88798083'],
#   'Brewery Name': 'Ballast Point Brewing Company'},
#  {'Coordinates': ['-117.157081', '32.889641'],
#   'Brewery Name': 'Ballast Point Brewing Company'},
#  {'Coordinates': ['-83.2218237', '35.3737065'],
#   'Brewery Name': 'Balsam Falls Brewing'},
#  {'Coordinates': ['-83.92432', '35.96654'],
#   'Brewery Name': 'Balter Beerworks'},
#  {'Coordinates': ['-86.08555156', '42.781287299999995'],
#   'Brewery Name': 'Bam Entertainment Center'},
#  {'Coordinates': ['-87.6750827', '41.96759539999999'],
#   'Brewery Name': 'Band Of Bohemia'},
#  {'Coordinates': ['-87.56215513', '33.19849071'],
#   'Brewery Name': 'Band of Brothers Brewing Company'},
#  {'Coordinates': ['-104.98741869999999', '39.728289700000005'],
#   'Brewery Name': 'Banded Oak Brewing Company'},
#  {'Coordinates': ['-124.4122494', '43.119157200000004'],
#   'Brewery Name': 'Bandon Brewing Company'},
#  {'Coordinates': ['-76.72782409999999', '42.61661956'],
#   'Brewery Name': 'Bandwagon Brewery'},
#  {'Coordinates': ['-120.6452338', '35.2615498'],
#   'Brewery Name': 'Bang the Drum Brewery'},
#  {'Coordinates': ['-96.42581655', '44.50839827'],
#   'Brewery Name': 'Bank Brewing Co'},
#  {'Coordinates': ['-96.56610883', '32.9029137'],
#   'Brewery Name': 'Bankhead Brewing Company'},
#  {'Coordinates': ['-80.85147552', '38.281622999999996'],
#   'Brewery Name': "Banning's Inc"},
#  {'Coordinates': ['-111.1770268', '45.775153700000004'],
#   'Brewery Name': 'Bar 3 BBQ and Brewing'},
#  {'Coordinates': ['-98.71854917', '31.19678472'],
#   'Brewery Name': 'Bar D Brew House'},
#  {'Coordinates': ['-75.16567302', '39.96707286'],
#   'Brewery Name': 'Bar Hygge / Brewery Techne'},
#  {'Coordinates': ['-135.309951', '57.049586'],
#   'Brewery Name': 'Baranof Island Brewing Co'},
#  {'Coordinates': ['-116.206883', '43.618407'],
#   'Brewery Name': 'Barbarian Brewing - Downtown Taproom'},
#  {'Coordinates': ['-116.27214099999999', '43.646318'],
#   'Brewery Name': 'Barbarian Brewing - Garden City'},
#  {'Coordinates': ['-77.00658302', '38.87165373'],
#   'Brewery Name': 'Bardo Brewpub'},
#  {'Coordinates': ['-83.92097890000001', '39.0419795'],
#   'Brewery Name': 'Bardwell Winery and Brewery'},
#  {'Coordinates': ['-97.13081959', '31.52488462'],
#   'Brewery Name': 'Bare Arms Brewing'},
#  {'Coordinates': ['-88.59075354', '44.07856457'],
#   'Brewery Name': 'Bare Bones Brewery'},
#  {'Coordinates': ['-122.4090405', '37.74000915'],
#   'Brewery Name': 'Barebottle Brewing Company'},
#  {'Coordinates': ['-70.92336518', '42.85606929'],
#   'Brewery Name': 'BareWolf Brewing'},
#  {'Coordinates': ['-123.4332787', '48.12098065'],
#   'Brewery Name': 'Barhop Brewing'},
#  {'Coordinates': ['-79.84360434', '36.06201036'],
#   'Brewery Name': 'Bark Brewing Company'},
#  {'Coordinates': ['-75.4867252', '43.7874658'],
#   'Brewery Name': 'BarkEater Craft Brewery'},
#  {'Coordinates': ['-97.69324870000001', '30.6608114'],
#   'Brewery Name': 'Barking Armadillo Brewing'},
#  {'Coordinates': ['-77.3995969', '39.38204685'],
#   'Brewery Name': 'Barley and Hops Grill'},
#  {'Coordinates': ['-114.3206399', '34.4770677'],
#   'Brewery Name': 'Barley Brothers Brewery'},
#  {'Coordinates': ['-117.82949620000001', '44.7787802'],
#   'Brewery Name': 'Barley Browns Brewpub'},
#  {'Coordinates': ['-75.32890575', '41.05236395'],
#   'Brewery Name': 'Barley Creek Brewing Co'},
#  {'Coordinates': ['-93.19848309999999', '45.036698200000004'],
#   'Brewery Name': 'Barley Johns Brewpub'},
#  {'Coordinates': ['-83.00276690000001', '39.9719408'],
#   'Brewery Name': "Barley's Brewing Company (Ale House No. 1)"},
#  {'Coordinates': ['-122.4339039', '45.51805087'],
#   'Brewery Name': 'Barley Sprouts Brewery'},
#  {'Coordinates': ['-85.84966443', '42.16834814'],
#   'Brewery Name': 'Barn Brewers'},
#  {'Coordinates': ['-93.83851429999999', '41.5996472'],
#   'Brewery Name': 'Barn Town Brewing Co.'},
#  {'Coordinates': ['-134.40596200000002', '58.300314'],
#   'Brewery Name': 'Barnaby Brewing Company'},
#  {'Coordinates': ['-73.50094256', '40.74420335'],
#   'Brewery Name': 'Barnshed Brewing'},
#  {'Coordinates': ['-70.31159594', '41.64913517'],
#   'Brewery Name': 'Barnstable Brewing'},
#  {'Coordinates': ['-88.4642861', '44.16805'],
#   'Brewery Name': 'Barrel 41 Brewing Co'},
#  {'Coordinates': ['-87.4722168', '46.54578'],
#   'Brewery Name': 'Barrel and Beam'},
#  {'Coordinates': ['-78.88891655', '35.89445737'],
#   'Brewery Name': 'Barrel Culture Brewing And Blending'},
#  {'Coordinates': ['-105.321458', '39.636163700000004'],
#   'Brewery Name': 'Barrel Dog Brewing'},
#  {'Coordinates': ['-117.22138500000001', '33.148790000000005'],
#   'Brewery Name': 'Barrel Harbor Brewing Co.'},
#  {'Coordinates': ['-122.4461033', '37.77576514'],
#   'Brewery Name': 'Barrel Head Brewhouse'},
#  {'Coordinates': ['-122.5309307', '45.7808639'],
#   'Brewery Name': 'Barrel Mountain Brewing'},
#  {'Coordinates': ['-93.08803482', '44.95106551'],
#   'Brewery Name': 'Barrel Theory Beer Company'},
#  {'Coordinates': ['-70.405728', '43.553358'],
#   'Brewery Name': 'Barreled Souls Brewing Company LLC'},
#  {'Coordinates': ['-105.2202098', '39.756210700000004'],
#   'Brewery Name': 'Barrels & Bottles Brewery'},
#  {'Coordinates': ['-110.95966499999999', '32.214613'],
#   'Brewery Name': 'Barrio Brewing Co'},
#  {'Coordinates': ['-97.53703133', '30.94295989'],
#   'Brewery Name': 'Barrow Brewing Company'},
#  {'Coordinates': ['-122.90708240000001', '44.5247777'],
#   'Brewery Name': 'Barsideous Brewing Co'},
#  {'Coordinates': ['-122.4087293', '37.78640638'],
#   'Brewery Name': 'Bartlett Hall'},
#  {'Coordinates': ['-82.15710792', '41.46560548'],
#   'Brewery Name': 'Bascule Brewery And Public House'},
#  {'Coordinates': ['-122.65611080000001', '45.5198818'],
#   'Brewery Name': 'Base Camp Brewing Co'},
#  {'Coordinates': ['-99.13928220000001', '30.05042839'],
#   'Brewery Name': 'Basement Brewers of Texas'},
#  {'Coordinates': ['-78.87398588', '38.0644451'],
#   'Brewery Name': 'Basic City Beer Co.'},
#  {'Coordinates': ['-86.92850063', '38.39736355'],
#   'Brewery Name': 'Basket Case Brewing Co'},
#  {'Coordinates': ['-90.503349', '38.482820000000004'],
#   'Brewery Name': 'Bastard Brothers Brewing Company'},
#  {'Coordinates': ['-122.57087290000001', '48.46080506'],
#   'Brewery Name': 'Bastion Brewing Company'},
#  {'Coordinates': ['-83.1440578', '42.4836283'],
#   'Brewery Name': 'Bastone Brewery'},
#  {'Coordinates': ['-83.088689', '42.3184806'],
#   'Brewery Name': 'Batch Brewing Co'},
#  {'Coordinates': ['-69.81414593', '43.91408541'],
#   'Brewery Name': 'Bath Brewing Company'},
#  {'Coordinates': ['-106.3007594', '35.8839054'],
#   'Brewery Name': 'Bathtub Row Brewing Co-op'},
#  {'Coordinates': ['-97.50849000000001', '35.619996'],
#   'Brewery Name': 'Battered Boar Brewing Co'},
#  {'Coordinates': ['-73.48739346', '43.41676935'],
#   'Brewery Name': 'Battle Hill Brewing Company'},
#  {'Coordinates': ['-71.45416113', '42.43001225'],
#   'Brewery Name': 'Battle Road Brewing Co'},
#  {'Coordinates': ['-117.22763400000001', '33.140153000000005'],
#   'Brewery Name': 'Battlemage Brewing Co'},
#  {'Coordinates': ['-93.237365', '45.042082'],
#   'Brewery Name': 'Bauhaus Brew Labs'},
#  {'Coordinates': ['-87.91923009', '43.11415845'],
#   'Brewery Name': 'Bavarian Bierhaus'},
#  {'Coordinates': ['-131.644822', '55.34321'],
#   'Brewery Name': 'Bawden Street Brewing Company'},
#  {'Coordinates': ['-70.219607', '44.09567728'],
#   'Brewery Name': 'Baxter Brewing Co, LLC'},
#  {'Coordinates': ['-117.2117833', '32.758075899999994'],
#   'Brewery Name': 'Bay City Brewing Co.'},
#  {'Coordinates': ['-114.02020879999999', '46.872595200000006'],
#   'Brewery Name': 'Bayern Brewing Inc.'},
#  {'Coordinates': ['-77.80208267', '35.958026000000004'],
#   'Brewery Name': 'BDD Brewing Company'},
#  {'Coordinates': ['-122.502981', '37.7252994'],
#   'Brewery Name': 'Beach Chalet Brewing Co'},
#  {'Coordinates': ['-74.0251959', '40.1812131'],
#   'Brewery Name': 'Beach Haus Brewery'},
#  {'Coordinates': ['-81.057048', '29.326634000000002'],
#   'Brewery Name': 'Beachside Brew Pub'},
#  {'Coordinates': ['-118.18947150000001', '33.77015096'],
#   'Brewery Name': 'Beachwood Blendery'},
#  {'Coordinates': ['-79.51785', '37.33585'], 'Brewery Name': "Beale's"},
#  {'Coordinates': ['-70.09605519', '44.02012732'],
#   'Brewery Name': 'Bear Bones Beer'},
#  {'Coordinates': ['-116.26085400000001', '43.620591999999995'],
#   'Brewery Name': 'Bear Island Brewing Company'},
#  {'Coordinates': ['-122.87130459999999', '38.611031700000005'],
#   'Brewery Name': 'Bear Republic Brewing Co'},
#  {'Coordinates': ['-122.71014050000001', '38.364970299999996'],
#   'Brewery Name': 'Bear Republic Brewing Co Pub & Restaurant - Lakeside'},
#  {'Coordinates': ['-117.226238', '33.188251'],
#   'Brewery Name': 'Bear Roots Brewing Company'},
#  {'Coordinates': ['-70.79073199999999', '43.027935'],
#   'Brewery Name': 'Beara Brewing Co.'},
#  {'Coordinates': ['-94.418276', '37.248046'],
#   'Brewery Name': 'Beard Engine Brewing Co'},
#  {'Coordinates': ['-86.786174', '36.181424'],
#   'Brewery Name': 'Bearded Iris Brewing'},
#  {'Coordinates': ['-84.95425838', '45.37533801'],
#   'Brewery Name': 'Beards Brewery'},
#  {'Coordinates': ['-85.249116', '45.304738'],
#   'Brewery Name': 'Beards Brewery Production Facility'},
#  {'Coordinates': ['-122.19140459999998', '47.7663209'],
#   'Brewery Name': 'Beardslee Public House'},
#  {'Coordinates': ['-149.41271030000001', '61.5752695'],
#   'Brewery Name': 'Bearpaw River Brewing Co'},
#  {'Coordinates': ['-82.843001', '35.53137'],
#   'Brewery Name': 'BearWaters Brewing Co'},
#  {'Coordinates': ['-73.311685', '41.12587'], 'Brewery Name': 'Beaver Beer Co'},
#  {'Coordinates': ['-98.66793299999999', '38.639049'],
#   'Brewery Name': "Beaver Brewery At Mo's Place"},
#  {'Coordinates': ['-80.31927929999999', '40.765055700000005'],
#   'Brewery Name': 'Beaver Brewing Co'},
#  {'Coordinates': ['-94.15733312', '45.5585455'],
#   'Brewery Name': 'Beaver Island Brewing Company'},
#  {'Coordinates': ['-112.6396875', '45.21575351'],
#   'Brewery Name': 'Beaverhead Brewing Co'},
#  {'Coordinates': ['-94.75955040000001', '34.1658072'],
#   'Brewery Name': 'Beavers Bend Brewery'},
#  {'Coordinates': ['-79.05582568', '38.16800319'],
#   'Brewery Name': 'Bedlam Brewing LLC'},
#  {'Coordinates': ['-92.835774', '38.479374'],
#   'Brewery Name': "Bee's Knees Ale House"},
#  {'Coordinates': ['-81.873356', '36.16819584'],
#   'Brewery Name': 'Beech Mountain Brewing Company'},
#  {'Coordinates': ['-111.30370090000001', '45.259632'],
#   'Brewery Name': 'Beehive Basin Brewery'},
#  {'Coordinates': ['-104.9417886', '39.928562299999996'],
#   'Brewery Name': 'Beer By Design Brewery'},
#  {'Coordinates': ['-86.74311848', '41.79322148'],
#   'Brewery Name': 'Beer Church Brewing Company'},
#  {'Coordinates': ['-84.771328', '37.6481'], 'Brewery Name': 'Beer Engine'},
#  {'Coordinates': ['-97.44112940000001', '35.2216069'],
#   'Brewery Name': 'Beer Is Good Brewing Company'},
#  {'Coordinates': ['-157.8218784', '21.29214406'],
#   'Brewery Name': 'Beer Lab HI'},
#  {'Coordinates': ['-116.95398059999998', '44.01504307'],
#   'Brewery Name': 'Beer Valley Brewing Co'},
#  {'Coordinates': ['-122.67189109999998', '45.62576802'],
#   'Brewery Name': 'Beerded Brothers Brewing'},
#  {'Coordinates': ['-117.29241599999999', '33.213927500000004'],
#   'Brewery Name': 'Belching Beaver Brewery'},
#  {'Coordinates': ['-117.241029', '33.202118199999994'],
#   'Brewery Name': 'Belching Beaver Brewery Tavern & Grill'},
#  {'Coordinates': ['-68.9880177', '44.4309432'],
#   'Brewery Name': 'Belfast Bay Brewing Co'},
#  {'Coordinates': ['-72.28542213', '43.10984838'],
#   'Brewery Name': 'Belgian Mare Brewery'},
#  {'Coordinates': ['-85.57887292', '42.29491555'],
#   'Brewery Name': "Bell's Eccentric Cafe"},
#  {'Coordinates': ['-82.48591', '42.823895'],
#   'Brewery Name': 'Bella Casa Di Vino'},
#  {'Coordinates': ['-97.545912', '35.522258'],
#   'Brewery Name': 'Belle Isle Restaurant and Brewing Co'},
#  {'Coordinates': ['-122.16693059999999', '47.62658069'],
#   'Brewery Name': 'Bellevue Brewing Co'},
#  {'Coordinates': ['-122.3456669', '47.614295299999995'],
#   'Brewery Name': 'Belltown Brewery'},
#  {'Coordinates': ['-117.4265497', '47.67645574'],
#   'Brewery Name': 'Bellwether Brewing Co'},
#  {'Coordinates': ['-77.70159029999999', '39.136424700000006'],
#   'Brewery Name': 'Belly Love Brewing Company'},
#  {'Coordinates': ['-118.14804540000002', '33.759551'],
#   'Brewery Name': 'Belmont Brewing Co'},
#  {'Coordinates': ['-86.58583931', '34.73272365'],
#   'Brewery Name': 'Below the Radar Brewing Co'},
#  {'Coordinates': ['-77.4172876', '38.9914289'],
#   'Brewery Name': 'Beltway Brewing Company'},
#  {'Coordinates': ['-94.88482747', '47.46990220000001'],
#   'Brewery Name': 'Bemidji Brewing Company'},
#  {'Coordinates': ['-82.5557931', '35.591275599999996'],
#   'Brewery Name': "Ben's Tune-Up / Ben's Beer"},
#  {'Coordinates': ['-76.30742245', '36.86493389'],
#   'Brewery Name': 'Benchtop Brewing Company'},
#  {'Coordinates': ['-121.31393119999998', '44.06051115'],
#   'Brewery Name': 'Bend Brewing Co'},
#  {'Coordinates': ['-87.78630172', '42.72641512'],
#   'Brewery Name': 'Benjamin Beer Co'},
#  {'Coordinates': ['-117.21785259999999', '47.6571208'],
#   'Brewery Name': "Bennidito's Brewpub"},
#  {'Coordinates': ['-96.00634511', '41.28489756'],
#   'Brewery Name': 'Benson Brewery'},
#  {'Coordinates': ['-122.83223000000001', '47.445115'],
#   'Brewery Name': 'Bent Bine Brew Co. LLC'},
#  {'Coordinates': ['-93.17364906', '45.02557829'],
#   'Brewery Name': 'Bent Brewstillery'},
#  {'Coordinates': ['-88.861232', '42.9348495'],
#   'Brewery Name': 'Bent Kettle Brewing Company'},
#  {'Coordinates': ['-92.12191709999999', '46.7676912'],
#   'Brewery Name': 'Bent Paddle Brewing Co'},
#  {'Coordinates': ['-91.1052085', '40.810612799999994'],
#   'Brewery Name': 'Bent River Brewing Co'},
#  {'Coordinates': ['-90.51736337', '41.50590516'],
#   'Brewery Name': 'Bent River Brewing Co'},
#  {'Coordinates': ['-90.5669283', '41.507633899999995'],
#   'Brewery Name': 'Bent River Brewing Co Production & Tasting Room'},
#  {'Coordinates': ['-94.1178372', '36.316827200000006'],
#   'Brewery Name': 'Bentonville Brewing Co'},
#  {'Coordinates': ['-72.61025086', '42.47779797'],
#   'Brewery Name': 'Berkshire Brewing Co Inc'},
#  {'Coordinates': ['-74.92998973', '39.79199228'],
#   'Brewery Name': 'Berlin Brewing Company'},
#  {'Coordinates': ['-113.89365500000001', '45.174557'],
#   'Brewery Name': 'Bertrams Salmon Valley Brewery'},
#  {'Coordinates': ['-117.87049309999999', '33.750037799999994'],
#   'Brewery Name': 'Berts Brewing Co.'},
#  {'Coordinates': ['-76.2381632', '41.05243327'],
#   'Brewery Name': 'Berwick Brewing Co'},
#  {'Coordinates': ['-82.55191879', '35.59166763'],
# ...
#  {'Coordinates': ['-79.04306419', '43.1729222'],
#   'Brewery Name': 'Brickyard Brewing Company'},
#  {'Coordinates': ['-73.9017521', '40.6943348'],
#   'Brewery Name': 'Bridge And Tunnel Brewery'},
#  {'Coordinates': ['-122.68486010000001', '45.53133335'],
#   'Brewery Name': 'BridgePort Brewing Co'},
#  {'Coordinates': ['-111.0526959', '45.6627215'],
#   'Brewery Name': 'Bridger Brewing Company'},
#  {'Coordinates': ['-90.05724959999999', '29.9627851'],
#   'Brewery Name': 'Brieux Carre Brewing Company'},
#  {'Coordinates': ['-95.15119250000001', '29.650113399999995'],
#   'Brewery Name': 'Brigadoon Brewery & Brew School'},
#  {'Coordinates': ['-79.27030152', '36.09926877'],
#   'Brewery Name': 'Bright Penny Brewing Company'},
#  {'Coordinates': ['-81.40637701', '41.64346969'],
#   'Brewery Name': 'Brim Kitchen and Brewery'},
#  {'Coordinates': ['-77.80412199999999', '43.185296'],
#   'Brewery Name': 'Brindle Haus Brewing Company'},
#  {'Coordinates': ['-84.545876', '39.192788'],
#   'Brewery Name': 'Brink Brewing Company'},
#  {'Coordinates': ['-75.02304749', '39.485955'],
#   'Brewery Name': 'Brinx Jones Brewery'},
#  {'Coordinates': ['-96.39640025', '42.50441425'],
#   'Brewery Name': 'Brioux City Brewery'},
#  {'Coordinates': ['-104.827401', '38.810861700000004'],
#   'Brewery Name': 'Bristol Brewing Co'},
#  {'Coordinates': ['-82.1842085', '36.59629295'],
#   'Brewery Name': 'Bristol Station Brews & Taproom'},
#  {'Coordinates': ['-85.58284599999999', '42.27977268'],
#   'Brewery Name': 'Brite Eyes Brewing Co'},
#  {'Coordinates': ['-121.84683159999999', '39.83081138'],
#   'Brewery Name': 'British Bulldog Brewery'},
#  {'Coordinates': ['-104.69113709999999', '40.42495461'],
#   'Brewery Name': 'Brix Taphouse and Brewery'},
#  {'Coordinates': ['-80.28285490000002', '40.70091875'],
#   'Brewery Name': 'Brixton Brewing'},
#  {'Coordinates': ['-72.66266463', '41.96200785'],
#   'Brewery Name': 'Broad Brook Brewing Company'},
#  {'Coordinates': ['-92.327968', '38.951342'],
#   'Brewery Name': 'Broadway Brewery'},
#  {'Coordinates': ['-95.79448895', '36.0502662'],
#   'Brewery Name': 'Broken Arrow Brewing Co.'},
#  {'Coordinates': ['-73.81903249999999', '40.9549645'],
#   'Brewery Name': 'Broken Bow Brewery'},
#  {'Coordinates': ['-116.104522', '44.896502000000005'],
#   'Brewery Name': 'Broken Horn Brewing Company'},
#  {'Coordinates': ['-73.41424776', '41.37097334'],
#   'Brewery Name': 'Broken Symmetry Gastro Brewery'},
#  {'Coordinates': ['-149.8437638', '61.2225517'],
#   'Brewery Name': 'Broken Tooth Brewing Co'},
#  {'Coordinates': ['-106.6175091', '35.11440682'],
#   'Brewery Name': 'Broken Trail Brewery & Distillery'},
#  {'Coordinates': ['-92.06931518', '31.12386287'],
#   'Brewery Name': 'Broken Wheel Brewery'},
#  {'Coordinates': ['-86.91414689', '40.45361124'],
#   'Brewery Name': 'Brokerage Brewing Company'},
#  {'Coordinates': ['-90.39577338', '36.75663108'],
#   'Brewery Name': 'Bronze Owl Brewing'},
#  {'Coordinates': ['-77.0579247', '39.1780888'],
#   'Brewery Name': 'Brookeville Beer Farm'},
#  {'Coordinates': ['-122.6553318', '45.6499058'],
#   'Brewery Name': 'Brothers Cascadia Brewing'},
#  {'Coordinates': ['-78.861099', '38.457570000000004'],
#   'Brewery Name': 'Brothers Craft Brewing'},
#  {'Coordinates': ['-74.72540127', '39.78817758'],
#   'Brewery Name': 'Brotherton Brewing Company'},
#  {'Coordinates': ['-97.124214', '31.56428'],
#   'Brewery Name': 'Brotherwell Brewing'},
#  {'Coordinates': ['-82.52572837', '35.57438843'],
#   'Brewery Name': 'Brouwerij Cursus Keme'},
#  {'Coordinates': ['-122.12254850000001', '47.7711936'],
#   'Brewery Name': 'Brouwerij Les Deplorables'},
#  {'Coordinates': ['-83.03578521', '42.71929931'],
#   'Brewery Name': 'Brown Iron Brewhouse'},
#  {'Coordinates': ['-73.34515821', '42.92661444'],
#   'Brewery Name': "Brown's Brewing Co"},
#  {'Coordinates': ['-73.68755002', '42.73567746'],
#   'Brewery Name': "Brown's Brewing Co"},
#  {'Coordinates': ['-80.01586879999999', '35.9709266'],
#   'Brewery Name': 'Brown Truck Brewery'},
#  {'Coordinates': ['-105.2293345', '40.014146200000006'],
#   'Brewery Name': 'BRU Handbuilt Ales and Eats'},
#  {'Coordinates': ['-122.12756370000001', '38.08086313'],
#   'Brewery Name': 'Bruehol Brewing LLC'},
#  {'Coordinates': ['-78.85014375', '35.70884819'],
#   'Brewery Name': 'Brueprint Brewing Company LLC'},
#  {'Coordinates': ['-117.8418759', '33.85793692'],
#   'Brewery Name': 'Bruery Terreux'},
#  {'Coordinates': ['-117.87916159999999', '33.8623093'],
#   'Brewery Name': 'Bruery, The'},
#  {'Coordinates': ['-72.9302577', '41.306163899999994'],
#   'Brewery Name': 'BruRm At Bar'},
#  {'Coordinates': ['-98.97836727', '42.53141502'],
#   'Brewery Name': 'Brush Creek Brewing Company'},
#  {'Coordinates': ['-71.47169613', '41.78983825'],
#   'Brewery Name': 'Brutopia Brewery and Kitchen'},
#  {'Coordinates': ['-97.90477894', '29.69091561'],
#   'Brewery Name': 'BS Brewing'},
#  {'Coordinates': ['-76.50290152', '40.11180762'],
#   'Brewery Name': 'Bubes Brewery'},
#  {'Coordinates': ['-82.41752143', '40.08367829'],
#   'Brewery Name': "Buck's Brewing Co"},
#  {'Coordinates': ['-121.88234779999999', '37.32530178'],
#   'Brewery Name': 'Camino Brewing Co LLC'},
#  {'Coordinates': ['-74.81946353', '39.086856'],
#   'Brewery Name': 'Bucket Brigade Brewery'},
#  {'Coordinates': ['-81.80391800000001', '41.477245'],
#   'Brewery Name': 'Buckeye Beer Engine'},
#  {'Coordinates': ['-82.488973', '39.928559'],
#   'Brewery Name': 'Buckeye Lake Brewery'},
#  {'Coordinates': ['-105.09257350000001', '40.4058904'],
#   'Brewery Name': 'Buckhorn Brewers LLC'},
#  {'Coordinates': ['-87.8034082', '41.8083636'],
#   'Brewery Name': 'BuckleDown Brewing'},
#  {'Coordinates': ['-95.4160849', '29.775978000000002'],
#   'Brewery Name': 'Buffalo Bayou Brewing Co'},
#  {'Coordinates': ['-122.0768666', '37.6770284'],
#   'Brewery Name': 'Buffalo Bills Brewery'},
#  {'Coordinates': ['-92.366648', '34.752615999999996'],
#   'Brewery Name': 'Buffalo Brewing Company At The Water Buffalo'},
#  {'Coordinates': ['-78.85968835', '42.87851264'],
#   'Brewery Name': 'Buffalo Brewing Company'},
#  {'Coordinates': ['-78.831057', '42.946564'],
#   'Brewery Name': 'Buffalo Brewpub'},
#  {'Coordinates': ['-100.8618267', '46.82409056'],
#   'Brewery Name': 'Buffalo Commons Brewing Company'},
#  {'Coordinates': ['-87.99776222', '42.17719457'],
#   'Brewery Name': 'Buffalo Creek Brewing'},
#  {'Coordinates': ['-80.32462582', '36.92079563'],
#   'Brewery Name': 'Buffalo Mountain Brewery'},
#  {'Coordinates': ['-78.87249292', '42.8696795'],
#   'Brewery Name': 'Buffalo RiverWorks Brewery'},
#  {'Coordinates': ['-87.90920890000001', '43.034132299999996'],
#   'Brewery Name': 'Buffalo Water Beer Co'},
#  {'Coordinates': ['-104.9488456', '39.7116689'],
#   'Brewery Name': 'Bull & Bush Brewery'},
#  {'Coordinates': ['-78.90481568', '35.9915653'],
#   'Brewery Name': 'Bull Durham Beer Co'},
#  {'Coordinates': ['-89.6174386', '44.951510999999996'],
#   'Brewery Name': 'Bull Falls Brewery LLC'},
#  {'Coordinates': ['-76.34206545', '37.02487345'],
#   'Brewery Name': 'Bull Island Brewing Company'},
#  {'Coordinates': ['-87.49513509999998', '41.679491'],
#   'Brewery Name': 'Bulldog Brewing'},
#  {'Coordinates': ['-77.051529', '41.23995479999999'],
#   'Brewery Name': 'Bullfrog Brewery - Production Only'},
#  {'Coordinates': ['-77.051529', '41.23995479999999'],
#   'Brewery Name': 'Bullfrog Brewery'},
#  {'Coordinates': ['-82.2695872', '27.922973100000004'],
#   'Brewery Name': 'Bullfrog Creek Brewing Company'},
#  {'Coordinates': ['-89.6383093', '42.60032375'],
#   'Brewery Name': 'Bullquarian Brewhouse, LLC'},
#  {'Coordinates': ['-75.49576861', '42.67156527'],
#   'Brewery Name': 'Bullthistle Brewing Co.'},
#  {'Coordinates': ['-123.835151', '46.191323499999996'],
#   'Brewery Name': 'Buoy Beer Company'},
#  {'Coordinates': ['-92.210993', '38.954685999999995'],
#   'Brewery Name': 'Bur Oak Brewing Company'},
#  {'Coordinates': ['-122.31456170000001', '47.526728600000006'],
#   'Brewery Name': 'Burdick Brewery'},
#  {'Coordinates': ['-105.0024095', '39.782516799999996'],
#   'Brewery Name': 'Burgundian Brewing Co.'},
#  {'Coordinates': ['-82.55379062', '35.5879562'],
#   'Brewery Name': 'Burial Beer Co'},
#  {'Coordinates': ['-75.21698640000001', '38.333644799999995'],
#   'Brewery Name': 'Burley Oak Craft Brewery'},
#  {'Coordinates': ['-86.82979191', '41.73849717'],
#   'Brewery Name': "Burn'Em Brewing"},
#  {'Coordinates': ['-118.3195014', '33.8036545'],
#   'Brewery Name': 'Burnin Daylight Brewing Company'},
#  {'Coordinates': ['-116.9717836', '32.81201287'],
#   'Brewery Name': 'Burning Beard Brewing'},
#  {'Coordinates': ['-122.65846950000001', '45.5233261'],
#   'Brewery Name': 'Burnside Brewing Co'},
#  {'Coordinates': ['-87.65722732', '41.93185255'],
#   'Brewery Name': 'Burnt City Brewing'},
#  {'Coordinates': ['-71.20968924', '43.58632316'],
#   'Brewery Name': 'Burnt Timber Brewing'},
#  {'Coordinates': ['-118.26532859999999', '46.0940928'],
#   'Brewery Name': 'Burwood Brewing Company'},
#  {'Coordinates': ['-106.63354640000001', '48.1938472'],
#   'Brewery Name': 'Busted Knuckle Brewery'},
#  {'Coordinates': ['-106.85776299999999', '40.510887'],
#   'Brewery Name': 'Butcherknife Brewing Company'},
#  {'Coordinates': ['-79.895238', '40.860914'],
#   'Brewery Name': 'Butler Brew Works'},
#  {'Coordinates': ['-112.52591969999999', '46.01246804'],
#   'Brewery Name': 'Butte Brewing Co'},
#  {'Coordinates': ['-75.1914973', '42.62396243'],
#   'Brewery Name': 'Butternuts Beer'},
#  {'Coordinates': ['-89.65050394', '39.8005279'],
#   'Brewery Name': 'Buzz Bomb Brewing Co'},
#  {'Coordinates': ['-134.645965', '58.387811'],
#   'Brewery Name': 'Forbidden Peak Brewery'},
#  {'Coordinates': ['-71.04970461', '41.55207456'],
#   'Brewery Name': 'Buzzards Bay Brewing Co'},
#  {'Coordinates': ['-104.9887246', '39.56211674'],
#   'Brewery Name': 'C.B. and Potts/Big Horn Brewery - Highlands Ranch'},
#  {'Coordinates': ['-105.0040899', '39.91376115'],
#   'Brewery Name': 'C.B. and Potts/Big Horn Brewery - Westminster'},
#  {'Coordinates': ['-80.60600028', '35.41573578'],
#   'Brewery Name': 'Cabarrus Brewing Company'},
#  {'Coordinates': ['-95.96694699999999', '36.1515468'],
#   'Brewery Name': 'Cabin Boys Brewery'},
#  {'Coordinates': ['-115.5506412', '48.393650799999996'],
#   'Brewery Name': 'Cabinet Mountain Brewing Co'},
#  {'Coordinates': ['-77.2705542', '38.9077525'],
#   'Brewery Name': 'Caboose Brewing Co.'},
#  {'Coordinates': ['-81.46300291', '30.671625300000002'],
#   'Brewery Name': 'Cafe Karibo'},
#  {'Coordinates': ['-82.660409', '27.770291999999998'],
#   'Brewery Name': 'Cage Brewing'},
#  {'Coordinates': ['-122.24408659999999', '47.7571424'],
#   'Brewery Name': 'Cairn Brewing'},
#  {'Coordinates': ['-92.04978922', '30.21549043'],
#   'Brewery Name': 'Cajun Brewing'},
#  {'Coordinates': ['-122.6633744', '42.18373846'],
#   'Brewery Name': 'Caldera Brewing Co'},
#  {'Coordinates': ['-82.7840735', '28.01394225'],
#   'Brewery Name': 'Caledonia Brewing'},
#  {'Coordinates': ['-85.42206083', '35.94460668'],
#   'Brewery Name': 'Calfkiller Brewing Co'},
#  {'Coordinates': ['-94.578762', '39.141723'],
#   'Brewery Name': 'Calibration Brewery'},
#  {'Coordinates': ['-122.83325020000001', '38.3845125'],
#   'Brewery Name': 'California Cider Co.'},
#  {'Coordinates': ['-117.21464879999999', '32.905002'],
#   'Brewery Name': 'California Wild Ales'},
#  {'Coordinates': ['-105.0435373', '39.778854100000004'],
#   'Brewery Name': 'Call To Arms Brewing Company'},
#  {'Coordinates': ['-103.9581938', '35.77706974'],
#   'Brewery Name': 'Callahan West Brewery'},
#  {'Coordinates': ['-94.574428', '39.138525'],
#   'Brewery Name': 'Callsign Brewing'},
#  {'Coordinates': ['-82.483799', '27.269363000000002'],
#   'Brewery Name': 'Calusa Brewing Company'},
#  {'Coordinates': ['-72.79259539', '41.96631414'],
#   'Brewery Name': 'Cambridge House Brew Pub - Granby'},
#  {'Coordinates': ['-121.93327430000001', '37.2870748'],
#   'Brewery Name': 'Campbell Brewing Co'},
#  {'Coordinates': ['-118.2462486', '34.192912'],
#   'Brewery Name': 'Can Of Worms Brewing'},
#  {'Coordinates': ['-71.41301096', '42.98495629999999'],
#   'Brewery Name': 'Candia Road Brewing / Nepenthe Ale House'},
#  {'Coordinates': ['-86.14245603', '39.79046798'],
#   'Brewery Name': 'Cannon Ball Brewing Company'},
#  {'Coordinates': ['-77.46012854', '37.54707897'],
#   'Brewery Name': 'Canon & Draw Brewing Company'},
#  {'Coordinates': ['-106.617653', '35.12025411'],
#   'Brewery Name': 'Canteen Brewhouse'},
#  {'Coordinates': ['-71.51484346', '43.38577573'],
#   'Brewery Name': 'Canterbury Aleworks'},
#  {'Coordinates': ['-83.45863309999999', '42.322478600000004'],
#   'Brewery Name': 'Canton Brew Works, LLC'},
#  {'Coordinates': ['-81.37453867', '40.7998289'],
#   'Brewery Name': 'Canton Brewing Company'},
#  {'Coordinates': ['-122.12883000000001', '37.834897'],
#   'Brewery Name': 'Canyon Club Brewery'},
#  {'Coordinates': ['-108.59167520000001', '45.74436502'],
#   'Brewery Name': 'Canyon Creek Brewing'},
#  {'Coordinates': ['-121.94788', '37.77114856'],
#   'Brewery Name': 'Canyon Lakes Golf Course & Brewery'},
#  {'Coordinates': ['-70.66509344', '42.61161602'],
#   'Brewery Name': 'Cape Ann Brewing Co'},
#  {'Coordinates': ['-75.992111', '37.269795'],
#   'Brewery Name': 'Cape Charles Brewing Company'},
#  {'Coordinates': ['-74.91285755', '39.00066318'],
#   'Brewery Name': 'Cape May Brewing Company'},
#  {'Coordinates': ['-76.33484565', '44.12823687'],
#   'Brewery Name': 'Cape Vincent Brewing Co'},
#  {'Coordinates': ['-89.51657978', '43.09489645'],
#   'Brewery Name': 'Capital Brewery Co Inc'},
#  {'Coordinates': ['-77.0082686', '38.897929299999994'],
#   'Brewery Name': 'Capitol City Brewing Co'},
#  {'Coordinates': ['-76.39947559999999', '37.082339000000005'],
#   'Brewery Name': 'Capstan Bar Brewing Company'},
#  {'Coordinates': ['-73.839113', '41.034859999999995'],
#   'Brewery Name': 'Captain Lawrence Brewing Co'},
#  {'Coordinates': ['-97.672065', '29.883798'],
#   'Brewery Name': 'Caracara Brewing Company'},
#  {'Coordinates': ['-107.2134909', '39.40060712'],
#   'Brewery Name': 'Carbondale Beer Works'},
#  {'Coordinates': ['-122.35339579999999', '48.4719343'],
#   'Brewery Name': 'Cardinal Craft Brewing Academy/ Skagit Valley College'},
#  {'Coordinates': ['-77.06089704', '42.15025771'],
#   'Brewery Name': "Carey's Brew House"},
#  {'Coordinates': ['-84.20121', '39.730102'],
#   'Brewery Name': 'Carillon Brewing Company'},
#  {'Coordinates': ['-89.09053', '42.2689989'],
#   'Brewery Name': 'Carlyle Brewing Co'},
#  {'Coordinates': ['-92.09418809', '46.78986799'],
#   'Brewery Name': 'Carmody Irish Pub & Brewing'},
#  {'Coordinates': ['-79.0627304', '35.9106269'],
#   'Brewery Name': 'Carolina Brewery - Chapel Hill'},
#  {'Coordinates': ['-79.1652429', '35.7438093'],
#   'Brewery Name': 'Carolina Brewery - Pittsboro'},
#  {'Coordinates': ['-78.85444105', '35.656105100000005'],
#   'Brewery Name': 'Carolina Brewing Co'},
#  {'Coordinates': ['-94.86534008', '42.06385868'],
#   'Brewery Name': 'Carroll Brewing Co.'},
#  {'Coordinates': ['-108.5016538', '45.78291334'],
#   'Brewery Name': 'Carters Brewing'},
#  {'Coordinates': ['-74.0381651', '40.4117685'],
#   'Brewery Name': 'Carton Brewing Co'},
#  {'Coordinates': ['-107.8800415', '37.2748415'],
#   'Brewery Name': 'Carver Brewing Co'},
#  {'Coordinates': ['-122.65600570000001', '45.5167536'],
#   'Brewery Name': 'Cascade Brewing Barrel House'},
#  {'Coordinates': ['-122.7900557', '45.4709556'],
#   'Brewery Name': 'Cascade Brewing Blending House'},
#  {'Coordinates': ['-122.699417', '45.478513'],
#   'Brewery Name': 'Cascade Brewing'},
#  {'Coordinates': ['-122.90017399999999', '47.04491273'],
#   'Brewery Name': 'Cascadia Brewing Co.'},
#  {'Coordinates': ['-91.6731853', '47.0194124'],
#   'Brewery Name': 'Castle Danger Brewery'},
#  {'Coordinates': ['-71.19186438', '42.16931297'],
#   'Brewery Name': 'Castle Island Brewing Co.'},
#  {'Coordinates': ['-94.57977386', '39.0924045'],
#   'Brewery Name': 'Casual Animal'},
#  {'Coordinates': ['-118.32563449999999', '33.3434987'],
#   'Brewery Name': 'Catalina Island Brew House'},
#  {'Coordinates': ['-81.68543695', '35.74471934'],
#   'Brewery Name': 'Catawba Brewing Co'},
#  {'Coordinates': ['-90.65372886', '42.51225898'],
#   'Brewery Name': 'Catfish Charlies / Catfish Creek Brew Pub'},
#  {'Coordinates': ['-90.2439837', '38.639489700000006'],
#   'Brewery Name': 'Cathedral Square Brewery'},
#  ...]

# %%
var locations = [
  {
    coordinates: [40.7128, -74.0059],
    state: {
      name: "New York State",
      population: 19795791
    },
    city: {
      name: "New York",
      population: 8550405
    }
  },
  {
    coordinates: [34.0522, -118.2437],
    state: {
      name: "California",
      population: 39250017
    },
    city: {
      name: "Lost Angeles",
      population: 3971883
    }
  },
  {
    coordinates: [41.8781, -87.6298],
    state: {
      name: "Illinois",
      population: 12671821
    },
    city: {
      name: "Chicago",
      population: 2695598
    }
  },
  {
    coordinates: [29.7604, -95.3698],
    state: {
      name: "Texas",
      population: 26960000
    },
    city: {
      name: "Houston",
      population: 2296224
    }
  },
  {
    coordinates: [41.2524, -95.9980],
    state: {
      name: "Nebraska",
      population: 1882000
    },
    city: {
      name: "Omaha",
      population: 446599
    }
  }
];
